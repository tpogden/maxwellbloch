# %% [markdown]
# # Linear Absorption — Beer–Lambert Law
#
# When an electromagnetic field is weak enough that it never significantly
# depletes the ground-state population, the medium responds linearly: the
# field amplitude decays exponentially with propagation distance.  This is
# the **Beer–Lambert law**,
#
# $$
# I(z, \omega) = I_0(\omega)\,e^{-\alpha(\omega)\,z},
# $$
#
# where the absorption coefficient is $\alpha(\omega) := k\chi_I(\omega)$
# (the wavenumber times the imaginary part of the susceptibility).
# Since $I \propto |\Omega|^2$ this is equivalent to
#
# $$
# |\Omega(z, \omega)| = |\Omega_0(\omega)|\,e^{-\alpha(\omega)\,z/2}.
# $$
#
# For the resonant two-level system $\alpha(0) = 2Ng/\Gamma$, giving
# $|\Omega(z)| = |\Omega_0|\,e^{-Ng\,z/\Gamma}$ at $\omega = 0$.
# We use $\Omega_0 = 10^{-3}\,\Gamma$ throughout.
#
# This notebook demonstrates:
#
# 1. How increasing optical depth attenuates the pulse.
# 2. The role of spontaneous decay in reaching a true Beer–Lambert steady state.
# 3. That the exponential attenuation is independent of pulse shape (Gaussian, CW).

# %% [markdown]
# ## Parameters
#
# The `interaction_strengths` parameter $Ng$ sets the coupling between field and
# medium.  It is proportional to atomic density $N$ and the dipole matrix element
# squared: $C \propto N |\mu|^2 / \hbar$.  In the weak-field limit the resonant
# absorption coefficient is $\alpha \propto Ng$, so doubling $Ng$ doubles the
# optical depth of the medium.
#
# We will compare three values:
#
# | $Ng$ | Character |
# |---|---|
# | 0.1 | Optically thin — pulse passes through almost unchanged |
# | 1.0 | Moderate absorption |
# | 10.0 | Optically thick — strong attenuation |

# %%
import numpy as np
import plotly.graph_objects as go
from maxwellbloch import mb_solve, plot

# %% [markdown]
# ## Optically thin medium — $Ng = 0.1$
#
# With very few atoms the pulse propagates essentially undistorted.
# There is a small reduction in amplitude and a slight group delay, but
# the pulse shape is preserved.

# %%
mb_solve_json_ng01 = """
{
  "atom": {
    "fields": [
      {
        "coupled_levels": [[0, 1]],
        "detuning": 0.0,
        "rabi_freq": 1.0e-3,
        "rabi_freq_t_args": {"ampl": 1.0, "centre": 0.0, "fwhm": 1.0},
        "rabi_freq_t_func": "gaussian"
      }
    ],
    "num_states": 2,
    "decays": [{"channels": [[0, 1]], "rate": 1.0}]
  },
  "t_min": -2.0,
  "t_max": 10.0,
  "t_steps": 100,
  "z_min": -0.2,
  "z_max": 1.2,
  "z_steps": 10,
  "interaction_strengths": [0.1],
  "savefile": "mbs-linear-absorption-ng01-decay"
}
"""

mbs_ng01 = mb_solve.MBSolve().from_json_str(mb_solve_json_ng01)
mbs_ng01.mbsolve(recalc=False);
# Out:
#   0%|          | 0/10 [00:00<?, ?z/s]
#  10%|█         | 1/10 [00:00<00:00, 689.63z/s, Ω_max=0.00626]
#  20%|██        | 2/10 [00:00<00:00, 266.52z/s, Ω_max=0.00619]
#  30%|███       | 3/10 [00:00<00:00, 236.50z/s, Ω_max=0.00612]
#  40%|████      | 4/10 [00:00<00:00, 215.61z/s, Ω_max=0.00605]
#  50%|█████     | 5/10 [00:00<00:00, 212.42z/s, Ω_max=0.00599]
#  60%|██████    | 6/10 [00:00<00:00, 206.47z/s, Ω_max=0.00592]
#  70%|███████   | 7/10 [00:00<00:00, 199.55z/s, Ω_max=0.00586]
#  80%|████████  | 8/10 [00:00<00:00, 201.01z/s, Ω_max=0.00579]
#  90%|█████████ | 9/10 [00:00<00:00, 197.80z/s, Ω_max=0.00576]
# 100%|██████████| 10/10 [00:00<00:00, 194.23z/s, Ω_max=0.00576]
# 100%|██████████| 10/10 [00:00<00:00, 192.43z/s, Ω_max=0.00576]
# Saving MBSolve to mbs-linear-absorption-ng01-decay.qu

# %%
fig = plot.field_spacetime(mbs_ng01)
fig.update_layout(title="|Ω(z, t)| — Gaussian pulse, Ng = 0.1 (optically thin)")
fig.show(renderer='notebook_connected')
# Out:
#         <script>
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.5.0.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="5b0c726a-fc92-44c8-b435-d0a78ea39f3a" class="plotly-graph-div" style="height:400px; width:700px;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("5b0c726a-fc92-44c8-b435-d0a78ea39f3a")) {                    Plotly.newPlot(                        "5b0c726a-fc92-44c8-b435-d0a78ea39f3a",                        [{"colorbar":{"title":{"text":"|Ω| (γ)"}},"colorscale":[[0.0,"rgb(247,251,255)"],[0.125,"rgb(222,235,247)"],[0.25,"rgb(198,219,239)"],[0.375,"rgb(158,202,225)"],[0.5,"rgb(107,174,214)"],[0.625,"rgb(66,146,198)"],[0.75,"rgb(33,113,181)"],[0.875,"rgb(8,81,156)"],[1.0,"rgb(8,48,107)"]],"x":{"dtype":"f8","bdata":"AAAAAAAAAMAUrkfhehT+vylcj8L1KPy\u002fPgrXo3A9+r9SuB6F61H4v2ZmZmZmZva\u002fexSuR+F69L+QwvUoXI\u002fyv6RwPQrXo\u002fC\u002fcD0K16Nw7b+amZmZmZnpv8T1KFyPwuW\u002f7FG4HoXr4b8oXI\u002fC9Sjcv3wUrkfhetS\u002foJmZmZmZyb+AFK5H4Xq0v4AUrkfheqQ\u002fgBSuR+F6xD\u002foUbgehevRP5iZmZmZmdk\u002fpHA9Ctej4D94FK5H4XrkP1C4HoXrUeg\u002fKFyPwvUo7D8AAAAAAADwP+xRuB6F6\u002fE\u002f1qNwPQrX8z\u002fC9Shcj8L1P65H4XoUrvc\u002fmJmZmZmZ+T+E61G4HoX7P3A9CtejcP0\u002fXI\u002fC9Shc\u002fz+kcD0K16MAQJqZmZmZmQFAkML1KFyPAkCE61G4HoUDQHoUrkfhegRAcD0K16NwBUBmZmZmZmYGQFyPwvUoXAdAUrgehetRCEBI4XoUrkcJQDwK16NwPQpAMjMzMzMzC0AoXI\u002fC9SgMQB6F61G4Hg1AFK5H4XoUDkAK16NwPQoPQAAAAAAAABBAexSuR+F6EED2KFyPwvUQQHA9CtejcBFA61G4HoXrEUBmZmZmZmYSQOF6FK5H4RJAXI\u002fC9ShcE0DXo3A9CtcTQFK4HoXrURRAzMzMzMzMFEBH4XoUrkcVQML1KFyPwhVAPQrXo3A9FkC4HoXrUbgWQDMzMzMzMxdArkfhehSuF0AoXI\u002fC9SgYQKRwPQrXoxhAHoXrUbgeGUCamZmZmZkZQBSuR+F6FBpAkML1KFyPGkAK16NwPQobQITrUbgehRtAAAAAAAAAHEB6FK5H4XocQPYoXI\u002fC9RxAcD0K16NwHUDsUbgehesdQGZmZmZmZh5A4
z65ZSxAaKKzPk02uZ97bc4+PTwa0YLE5T5FmWKvIcH8PiXIawDLiBE\u002fp+luYlu+Iz9eNhjTZ4Y0P66ipJEos0M\u002f8SZylex0UT8qv5nIT5BcP7wGsO1Jk2U\u002fb3O2cZIXbj8bnvjx9F9zP2Cq6eDHCHc\u002fT7sZK4VIeT+3H9YnPJ95P\u002fUZ0nD5+Hc\u002fea+rRzu1dD\u002f4rG0g3INwP+VQcEkYUmg\u002fQjckI42IYD9t\u002f4DMAMFUP7Pbdj9tDUg\u002fw3GLtmW8OT8n3jzbgmwpP8TovmkmMBc\u002fAgj8rpyGAz\u002fJfhF0OVzuPn9woM2xytU+Zt708NvhvD6TWHO1xquhPpnYxTu59oM+ZR\u002froLXSZD6q9qQhcg1EPjL8e0wX1CE+xCz63upE\u002 ...

# %% [markdown]
# ## Moderate optical depth — $Ng = 1$
#
# With $Ng = 1$ the absorption is noticeable: the output amplitude is
# appreciably smaller than the input and the pulse acquires a clear group
# delay as the leading edge drives the atoms before the trailing edge arrives.

# %%
mb_solve_json_ng1 = """
{
  "atom": {
    "fields": [
      {
        "coupled_levels": [[0, 1]],
        "detuning": 0.0,
        "rabi_freq": 1.0e-3,
        "rabi_freq_t_args": {"ampl": 1.0, "centre": 0.0, "fwhm": 1.0},
        "rabi_freq_t_func": "gaussian"
      }
    ],
    "num_states": 2,
    "decays": [{"channels": [[0, 1]], "rate": 1.0}]
  },
  "t_min": -2.0,
  "t_max": 10.0,
  "t_steps": 100,
  "z_min": -0.2,
  "z_max": 1.2,
  "z_steps": 20,
  "z_steps_inner": 2,
  "interaction_strengths": [1.0],
  "savefile": "mbs-linear-absorption-ng1-decay"
}
"""

mbs_ng1 = mb_solve.MBSolve().from_json_str(mb_solve_json_ng1)
mbs_ng1.mbsolve(recalc=False);
# Out:
#   0%|          | 0/20 [00:00<?, ?z/s]
#   5%|▌         | 1/20 [00:00<00:00, 1908.24z/s, Ω_max=0.00626]
#  10%|█         | 2/20 [00:00<00:00, 331.03z/s, Ω_max=0.00626]
#  15%|█▌        | 3/20 [00:00<00:00, 256.24z/s, Ω_max=0.00609]
#  20%|██        | 4/20 [00:00<00:00, 240.76z/s, Ω_max=0.00576]
#  25%|██▌       | 5/20 [00:00<00:00, 227.75z/s, Ω_max=0.00547]
#  30%|███       | 6/20 [00:00<00:00, 219.31z/s, Ω_max=0.00521]
#  35%|███▌      | 7/20 [00:00<00:00, 216.33z/s, Ω_max=0.00496]
#  40%|████      | 8/20 [00:00<00:00, 213.36z/s, Ω_max=0.00472]
#  45%|████▌     | 9/20 [00:00<00:00, 212.27z/s, Ω_max=0.00449]
#  50%|█████     | 10/20 [00:00<00:00, 210.53z/s, Ω_max=0.00427]
#  55%|█████▌    | 11/20 [00:00<00:00, 208.78z/s, Ω_max=0.00406]
#  60%|██████    | 12/20 [00:00<00:00, 208.19z/s, Ω_max=0.00386]
#  65%|██████▌   | 13/20 [00:00<00:00, 204.97z/s, Ω_max=0.00366]
#  70%|███████   | 14/20 [00:00<00:00, 204.88z/s, Ω_max=0.00348]
#  75%|███████▌  | 15/20 [00:00<00:00, 204.55z/s, Ω_max=0.0033]
#  80%|████████  | 16/20 [00:00<00:00, 202.94z/s, Ω_max=0.00313]
#  85%|████████▌ | 17/20 [00:00<00:00, 203.10z/s, Ω_max=0.00297]
#  90%|█████████ | 18/20 [00:00<00:00, 202.90z/s, Ω_max=0.00297]
#  95%|█████████▌| 19/20 [00:00<00:00, 202.69z/s, Ω_max=0.00297]
# 100%|██████████| 20/20 [00:00<00:00, 202.86z/s, Ω_max=0.00297]
# 100%|██████████| 20/20 [00:00<00:00, 201.90z/s, Ω_max=0.00297]
# Saving MBSolve to mbs-linear-absorption-ng1-decay.qu

# %%
fig = plot.field_spacetime(mbs_ng1)
fig.update_layout(title="|Ω(z, t)| — Gaussian pulse, Ng = 1")
fig.show(renderer='notebook_connected')
# Out:
#         <script>
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.5.0.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="dbdf8ece-4a98-436a-b231-d9cfc4b88f9c" class="plotly-graph-div" style="height:400px; width:700px;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("dbdf8ece-4a98-436a-b231-d9cfc4b88f9c")) {                    Plotly.newPlot(                        "dbdf8ece-4a98-436a-b231-d9cfc4b88f9c",                        [{"colorbar":{"title":{"text":"|Ω| (γ)"}},"colorscale":[[0.0,"rgb(247,251,255)"],[0.125,"rgb(222,235,247)"],[0.25,"rgb(198,219,239)"],[0.375,"rgb(158,202,225)"],[0.5,"rgb(107,174,214)"],[0.625,"rgb(66,146,198)"],[0.75,"rgb(33,113,181)"],[0.875,"rgb(8,81,156)"],[1.0,"rgb(8,48,107)"]],"x":{"dtype":"f8","bdata":"AAAAAAAAAMAUrkfhehT+vylcj8L1KPy\u002fPgrXo3A9+r9SuB6F61H4v2ZmZmZmZva\u002fexSuR+F69L+QwvUoXI\u002fyv6RwPQrXo\u002fC\u002fcD0K16Nw7b+amZmZmZnpv8T1KFyPwuW\u002f7FG4HoXr4b8oXI\u002fC9Sjcv3wUrkfhetS\u002foJmZmZmZyb+AFK5H4Xq0v4AUrkfheqQ\u002fgBSuR+F6xD\u002foUbgehevRP5iZmZmZmdk\u002fpHA9Ctej4D94FK5H4XrkP1C4HoXrUeg\u002fKFyPwvUo7D8AAAAAAADwP+xRuB6F6\u002fE\u002f1qNwPQrX8z\u002fC9Shcj8L1P65H4XoUrvc\u002fmJmZmZmZ+T+E61G4HoX7P3A9CtejcP0\u002fXI\u002fC9Shc\u002fz+kcD0K16MAQJqZmZmZmQFAkML1KFyPAkCE61G4HoUDQHoUrkfhegRAcD0K16NwBUBmZmZmZmYGQFyPwvUoXAdAUrgehetRCEBI4XoUrkcJQDwK16NwPQpAMjMzMzMzC0AoXI\u002fC9SgMQB6F61G4Hg1AFK5H4XoUDkAK16NwPQoPQAAAAAAAABBAexSuR+F6EED2KFyPwvUQQHA9CtejcBFA61G4HoXrEUBmZmZmZmYSQOF6FK5H4RJAXI\u002fC9ShcE0DXo3A9CtcTQFK4HoXrURRAzMzMzMzMFEBH4XoUrkcVQML1KFyPwhVAPQrXo3A9FkC4HoXrUbgWQDMzMzMzMxdArkfhehSuF0AoXI\u002fC9SgYQKRwPQrXoxhAHoXrUbgeGUCamZmZmZkZQBSuR+F6FBpAkML1KFyPGkAK16NwPQobQITrUbgehRtAAAAAAAAAHEB6FK5H4X
UrL3uPuqi0EX\u002fV5GRsoLTnJanJm66Ms3kZNUNlkHixM5zJ9k2iVK+KKUTom2AsrNAlTycC3gCrE+x8zvIjyKbIbKyKJ+GIpwihNUnjt0Sgy0reeeUg\u002fKJEd\u002f20FM6kneRBoGaa9EieTcYu2Zbx5JsZxi7ZlvHk+qnYXNQ1llz65ZSxAaKKzPk02uZ97bc4+PTwa0YLE5T5FmWKvIcH8PiXIawDLiBE\u002fp+luYlu+Iz9eNhjTZ4Y0P66ipJEos0M\u002f8SZylex0UT8qv5nIT5BcP7wGsO1Jk2U\u002fb3O2cZIXbj8bnvjx9F9zP2Cq6eDHCHc\u002fT7sZK4VIeT+3H9YnPJ95P\u002fUZ0nD5+Hc\u002fea+rRzu1dD\u002f4rG0g3INwP+VQcEkYUmg\u002fQjckI42IYD9t\u002f4DMAMFUP7Pbdj9tDUg\u002fw3GLtmW8OT8n ...

# %% [markdown]
# ## Optically thick medium — $Ng = 10$
#
# With $Ng = 10$ the medium is strongly absorbing.  The pulse is heavily
# attenuated and significantly reshaped: the leading spectral components
# are absorbed first, delaying the effective peak and broadening the
# transmitted pulse.

# %%
mb_solve_json_ng10 = """
{
  "atom": {
    "fields": [
      {
        "coupled_levels": [[0, 1]],
        "detuning": 0.0,
        "rabi_freq": 1.0e-3,
        "rabi_freq_t_args": {"ampl": 1.0, "centre": 0.0, "fwhm": 1.0},
        "rabi_freq_t_func": "gaussian"
      }
    ],
    "num_states": 2,
    "decays": [{"channels": [[0, 1]], "rate": 1.0}]
  },
  "t_min": -2.0,
  "t_max": 10.0,
  "t_steps": 100,
  "z_min": -0.2,
  "z_max": 1.2,
  "z_steps": 100,
  "z_steps_inner": 2,
  "interaction_strengths": [10.0],
  "savefile": "mbs-linear-absorption-ng10-decay"
}
"""

mbs_ng10 = mb_solve.MBSolve().from_json_str(mb_solve_json_ng10)
mbs_ng10.mbsolve(recalc=False);
# Out:
#   0%|          | 0/100 [00:00<?, ?z/s]
#   1%|          | 1/100 [00:00<00:00, 2183.40z/s, Ω_max=0.00626]
#   2%|▏         | 2/100 [00:00<00:00, 343.81z/s, Ω_max=0.00626]
#   3%|▎         | 3/100 [00:00<00:00, 274.47z/s, Ω_max=0.00626]
#   4%|▍         | 4/100 [00:00<00:00, 241.01z/s, Ω_max=0.00626]
#   5%|▌         | 5/100 [00:00<00:00, 224.01z/s, Ω_max=0.00626]
#   6%|▌         | 6/100 [00:00<00:00, 219.93z/s, Ω_max=0.00626]
#   7%|▋         | 7/100 [00:00<00:00, 211.30z/s, Ω_max=0.00626]
#   8%|▊         | 8/100 [00:00<00:00, 205.61z/s, Ω_max=0.00626]
#   9%|▉         | 9/100 [00:00<00:00, 203.45z/s, Ω_max=0.00626]
#  10%|█         | 10/100 [00:00<00:00, 201.38z/s, Ω_max=0.00626]
#  11%|█         | 11/100 [00:00<00:00, 200.30z/s, Ω_max=0.00626]
#  12%|█▏        | 12/100 [00:00<00:00, 199.63z/s, Ω_max=0.00626]
#  13%|█▎        | 13/100 [00:00<00:00, 198.63z/s, Ω_max=0.00626]
#  14%|█▍        | 14/100 [00:00<00:00, 197.69z/s, Ω_max=0.00626]
#  15%|█▌        | 15/100 [00:00<00:00, 197.96z/s, Ω_max=0.0056]
#  16%|█▌        | 16/100 [00:00<00:00, 197.56z/s, Ω_max=0.00508]
#  17%|█▋        | 17/100 [00:00<00:00, 198.87z/s, Ω_max=0.0046]
#  18%|█▊        | 18/100 [00:00<00:00, 198.41z/s, Ω_max=0.00416]
#  19%|█▉        | 19/100 [00:00<00:00, 198.64z/s, Ω_max=0.00376]
#  20%|██        | 20/100 [00:00<00:00, 197.65z/s, Ω_max=0.00376]
#  20%|██        | 20/100 [00:00<00:00, 197.65z/s, Ω_max=0.00339]
#  21%|██        | 21/100 [00:00<00:00, 197.65z/s, Ω_max=0.00304]
#  22%|██▏       | 22/100 [00:00<00:00, 197.65z/s, Ω_max=0.00276]
#  23%|██▎       | 23/100 [00:00<00:00, 197.65z/s, Ω_max=0.00251]
#  24%|██▍       | 24/100 [00:00<00:00, 197.65z/s, Ω_max=0.00228]
#  25%|██▌       | 25/100 [00:00<00:00, 197.65z/s, Ω_max=0.00207]
#  26%|██▌       | 26/100 [00:00<00:00, 197.65z/s, Ω_max=0.00187]
#  27%|██▋       | 27/100 [00:00<00:00, 197.65z/s, Ω_max=0.00169]
#  28%|██▊       | 28/100 [00:00<00:00, 197.65z/s, Ω_max=0.00153]
#  29%|██▉       | 29/100 [00:00<00:00, 197.65z/s, Ω_max=0.00138]
#  30%|███       | 30/100 [00:00<00:00, 197.65z/s, Ω_max=0.00126]
#  31%|███       | 31/100 [00:00<00:00, 197.65z/s, Ω_max=0.00115]
#  32%|███▏      | 32/100 [00:00<00:00, 197.65z/s, Ω_max=0.00105]
#  33%|███▎      | 33/100 [00:00<00:00, 197.65z/s, Ω_max=0.000954]
#  34%|███▍      | 34/100 [00:00<00:00, 197.65z/s, Ω_max=0.000867]
#  35%|███▌      | 35/100 [00:00<00:00, 197.65z/s, Ω_max=0.000786]
#  36%|███▌      | 36/100 [00:00<00:00, 197.65z/s, Ω_max=0.000712]
#  37%|███▋      | 37/100 [00:00<00:00, 197.65z/s, Ω_max=0.000643]
#  38%|███▊      | 38/100 [00:00<00:00, 197.65z/s, Ω_max=0.000588]
#  39%|███▉      | 39/100 [00:00<00:00, 197.65z/s, Ω_max=0.000539]
#  40%|████      | 40/100 [00:00<00:00, 173.64z/s, Ω_max=0.000539]
#  40%|████      | 40/100 [00:00<00:00, 173.64z/s, Ω_max=0.000493]
#  41%|████      | 41/100 [00:00<00:00, 173.64z/s, Ω_max=0.000451]
#  42%|████▏     | 42/100 [00:00<00:00, 173.64z/s, Ω_max=0.000412]
#  43%|████▎     | 43/100 [00:00<00:00, 173.64z/s, Ω_max=0.000375]
#  44%|████▍     | 44/100 [00:00<00:00, 173.64z/s, Ω_max=0.000358]
#  45%|████▌     | 45/100 [00:00<00:00, 173.64z/s, Ω_max=0.000341]
#  46%|████▌     | 46/100 [00:00<00:00, 173.64z/s, Ω_max=0.000324]
#  47%|████▋     | 47/100 [00:00<00:00, 173.64z/s, Ω_max=0.000306]
#  48%|████▊     | 48/100 [00:00<00:00, 173.64z/s, Ω_max=0.000287]
#  49%|████▉     | 49/100 [00:00<00:00, 173.64z/s, Ω_max=0.000276]
#  50%|█████     | 50/100 [00:00<00:00, 173.64z/s, Ω_max=0.000266]
#  51%|█████     | 51/100 [00:00<00:00, 173.64z/s, Ω_max=0.000254]
#  52%|█████▏    | 52/100 [00:00<00:00, 173.64z/s, Ω_max=0.000242]
#  53%|█████▎    | 53/100 [00:00<00:00, 173.64z/s, Ω_max=0.000229]
#  54%|█████▍    | 54/100 [00:00<00:00, 173.64z/s, Ω_max=0.000216]
#  55%|█████▌    | 55/100 [00:00<00:00, 173.64z/s, Ω_max=0.000203]
#  56%|█████▌    | 56/100 [00:00<00:00, 173.64z/s, Ω_max=0.00019]
#  57%|█████▋    | 57/100 [00:00<00:00, 173.64z/s, Ω_max=0.00018]
#  58%|█████▊    | 58/100 [00:00<00:00, 173.64z/s, Ω_max=0.000172]
#  59%|█████▉    | 59/100 [00:00<00:00, 173.64z/s, Ω_max=0.000164]
#  60%|██████    | 60/100 [00:00<00:00, 183.77z/s, Ω_max=0.000164]
#  60%|██████    | 60/100 [00:00<00:00, 183.77z/s, Ω_max=0.000156]
#  61%|██████    | 61/100 [00:00<00:00, 183.77z/s, Ω_max=0.000148]
#  62%|██████▏   | 62/100 [00:00<00:00, 183.77z/s, Ω_max=0.00014]
#  63%|██████▎   | 63/100 [00:00<00:00, 183.77z/s, Ω_max=0.000131]
#  64%|██████▍   | 64/100 [00:00<00:00, 183.77z/s, Ω_max=0.000123]
#  65%|██████▌   | 65/100 [00:00<00:00, 183.77z/s, Ω_max=0.000115]
#  66%|██████▌   | 66/100 [00:00<00:00, 183.77z/s, Ω_max=0.000107]
#  67%|██████▋   | 67/100 [00:00<00:00, 183.77z/s, Ω_max=0.000102]
#  68%|██████▊   | 68/100 [00:00<00:00, 183.77z/s, Ω_max=9.71e-05]
#  69%|██████▉   | 69/100 [00:00<00:00, 183.77z/s, Ω_max=9.23e-05]
#  70%|███████   | 70/100 [00:00<00:00, 183.77z/s, Ω_max=8.75e-05]
#  71%|███████   | 71/100 [00:00<00:00, 183.77z/s, Ω_max=8.27e-05]
#  72%|███████▏  | 72/100 [00:00<00:00, 183.77z/s, Ω_max=7.8e-05]
#  73%|███████▎  | 73/100 [00:00<00:00, 183.77z/s, Ω_max=7.38e-05]
#  74%|███████▍  | 74/100 [00:00<00:00, 183.77z/s, Ω_max=7.1e-05]
#  75%|███████▌  | 75/100 [00:00<00:00, 183.77z/s, Ω_max=6.79e-05]
#  76%|███████▌  | 76/100 [00:00<00:00, 183.77z/s, Ω_max=6.47e-05]
#  77%|███████▋  | 77/100 [00:00<00:00, 183.77z/s, Ω_max=6.13e-05]
#  78%|███████▊  | 78/100 [00:00<00:00, 183.77z/s, Ω_max=5.97e-05]
#  79%|███████▉  | 79/100 [00:00<00:00, 183.77z/s, Ω_max=5.84e-05]
#  80%|████████  | 80/100 [00:00<00:00, 188.08z/s, Ω_max=5.84e-05]
#  80%|████████  | 80/100 [00:00<00:00, 188.08z/s, Ω_max=5.68e-05]
#  81%|████████  | 81/100 [00:00<00:00, 188.08z/s, Ω_max=5.5e-05]
#  82%|████████▏ | 82/100 [00:00<00:00, 188.08z/s, Ω_max=5.3e-05]
#  83%|████████▎ | 83/100 [00:00<00:00, 188.08z/s, Ω_max=5.09e-05]
#  84%|████████▍ | 84/100 [00:00<00:00, 188.08z/s, Ω_max=4.87e-05]
#  85%|████████▌ | 85/100 [00:00<00:00, 188.08z/s, Ω_max=4.64e-05]
#  86%|████████▌ | 86/100 [00:00<00:00, 188.08z/s, Ω_max=4.52e-05]
#  87%|████████▋ | 87/100 [00:00<00:00, 188.08z/s, Ω_max=4.52e-05]
#  88%|████████▊ | 88/100 [00:00<00:00, 188.08z/s, Ω_max=4.52e-05]
#  89%|████████▉ | 89/100 [00:00<00:00, 188.08z/s, Ω_max=4.52e-05]
#  90%|█████████ | 90/100 [00:00<00:00, 188.08z/s, Ω_max=4.52e-05]
#  91%|█████████ | 91/100 [00:00<00:00, 188.08z/s, Ω_max=4.52e-05]
#  92%|█████████▏| 92/100 [00:00<00:00, 188.08z/s, Ω_max=4.52e-05]
#  93%|█████████▎| 93/100 [00:00<00:00, 188.08z/s, Ω_max=4.52e-05]
#  94%|█████████▍| 94/100 [00:00<00:00, 188.08z/s, Ω_max=4.52e-05]
#  95%|█████████▌| 95/100 [00:00<00:00, 188.08z/s, Ω_max=4.52e-05]
#  96%|█████████▌| 96/100 [00:00<00:00, 188.08z/s, Ω_max=4.52e-05]
#  97%|█████████▋| 97/100 [00:00<00:00, 188.08z/s, Ω_max=4.52e-05]
#  98%|█████████▊| 98/100 [00:00<00:00, 188.08z/s, Ω_max=4.52e-05]
#  99%|█████████▉| 99/100 [00:00<00:00, 188.08z/s, Ω_max=4.52e-05]
# 100%|██████████| 100/100 [00:00<00:00, 191.99z/s, Ω_max=4.52e-05]
# 100%|██████████| 100/100 [00:00<00:00, 191.99z/s, Ω_max=4.52e-05]
# 100%|██████████| 100/100 [00:00<00:00, 188.28z/s, Ω_max=4.52e-05]
# Saving MBSolve to mbs-linear-absorption-ng10-decay.qu

# %%
fig = plot.field_spacetime(mbs_ng10)
fig.update_layout(title="|Ω(z, t)| — Gaussian pulse, Ng = 10 (optically thick)")
fig.show(renderer='notebook_connected')
# Out:
#         <script>
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.5.0.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="df4a8c97-1fc1-4b2b-aebc-3bbde7afb280" class="plotly-graph-div" style="height:400px; width:700px;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("df4a8c97-1fc1-4b2b-aebc-3bbde7afb280")) {                    Plotly.newPlot(                        "df4a8c97-1fc1-4b2b-aebc-3bbde7afb280",                        [{"colorbar":{"title":{"text":"|Ω| (γ)"}},"colorscale":[[0.0,"rgb(247,251,255)"],[0.125,"rgb(222,235,247)"],[0.25,"rgb(198,219,239)"],[0.375,"rgb(158,202,225)"],[0.5,"rgb(107,174,214)"],[0.625,"rgb(66,146,198)"],[0.75,"rgb(33,113,181)"],[0.875,"rgb(8,81,156)"],[1.0,"rgb(8,48,107)"]],
    y=np.abs(mbs_ng01.Omegas_zt[0, 0, :]),
    mode="lines",
    name="input",
    line=dict(dash="dash", color="black"),
))

for mbs, label, color in [
    (mbs_ng01, "Ng = 0.1", "#636EFA"),
    (mbs_ng1,  "Ng = 1",   "#EF553B"),
    (mbs_ng10, "Ng = 10",  "#00CC96"),
]:
    fig.add_trace(go.Scatter(
        x=mbs.tlist,
        y=np.abs(mbs.Omegas_zt[0, -1, :]),
        mode="lines",
        name=label,
        line=dict(color=color),
    ))

fig.update_layout(
    title="Output pulse envelope |Ω(z=1, t)| vs optical depth",
    xaxis_title="t (γ⁻¹)",
    yaxis_title="|Ω| (γ)",
    template="maxwellbloch",
    width=700,
    height=400,
)
fig.show(renderer='notebook_connected')
# Out:
#         <script>
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.5.0.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="44dc8c2f-f4d4-4965-bf5d-c37eb4223c92" class="plotly-graph-div" style="height:400px; width:700px;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("44dc8c2f-f4d4-4965-bf5d-c37eb4223c92")) {                    Plotly.newPlot(                        "44dc8c2f-f4d4-4965-bf5d-c37eb4223c92",                        [{"line":{"color":"black","dash":"dash"},"mode":"lines","name":"input","x":{"dtype":"f8","bdata":"AAAAAAAAAMAUrkfhehT+vylcj8L1KPy\u002fPgrXo3A9+r9SuB6F61H4v2ZmZmZmZva\u002fexSuR+F69L+QwvUoXI\u002fyv6RwPQrXo\u002fC\u002fcD0K16Nw7b+amZmZmZnpv8T1KFyPwuW\u002f7FG4HoXr4b8oXI\u002fC9Sjcv3wUrkfhetS\u002foJmZmZmZyb+AFK5H4Xq0v4AUrkfheqQ\u002fgBSuR+F6xD\u002foUbgehevRP5iZmZmZmdk\u002fpHA9Ctej4D94FK5H4XrkP1C4HoXrUeg\u002fKFyPwvUo7D8AAAAAAADwP+xRuB6F6\u002fE\u002f1qNwPQrX8z\u002fC9Shcj8L1P65H4XoUrvc\u002fmJmZmZmZ+T+E61G4HoX7P3A9CtejcP0\u002fXI\u002fC9Shc\u002fz+kcD0K16MAQJqZmZmZmQFAkML1KFyPAkCE61G4HoUDQHoUrkfhegRAcD0K16NwBUBmZmZmZmYGQFyPwvUoXAdAUrgehetRCEBI4XoUrkcJQDwK16NwPQpAMjMzMzMzC0AoXI\u002fC9SgMQB6F61G4Hg1AFK5H4XoUDkAK16NwPQoPQAAAAAAAABBAexSuR+F6EED2KFyPwvUQQHA9CtejcBFA61G4HoXrEUBmZmZmZmYSQOF6FK5H4RJAXI\u002fC9ShcE0DXo3A9CtcTQFK4HoXrURRAzMzMzMzMFEBH4XoUrkcVQML1KFyPwhVAPQrXo3A9FkC4HoXrUbgWQDMzMzMzMxdArkfhehSuF0AoXI\u002fC9SgYQKRwPQrXoxhAHoXrUbgeGUCamZmZmZkZQBSuR+F6FBpAkML1KFyPGkAK16NwPQobQITrUbgehRtAAAAAAAAAHEB6FK5H4XocQPYoXI\u002fC9RxAcD0K16NwHUDsUbgehesdQGZmZmZmZh5A4HoUrkfhHkBcj8L1KFwfQNajcD0K1x9AKVyPwvUoIEBmZmZmZmYgQKRwPQrXoyBA4XoUrkf
K5H4Xq0v4AUrkfheqQ\u002fgBSuR+F6xD\u002foUbgehevRP5iZmZmZmdk\u002fpHA9Ctej4D94FK5H4XrkP1C4HoXrUeg\u002fKFyPwvUo7D8AAAAAAADwP+xRuB6F6\u002fE\u002f1qNwPQrX8z\u002fC9Shcj8L1P65H4XoUrvc\u002fmJmZmZmZ+T+E61G4HoX7P3A9CtejcP0\u002fXI\u002fC9Shc\u002fz+kcD0K16MAQJqZmZmZmQFAkML1KFyPAkCE61G4HoUDQHoUrkfhegRAcD0K16NwBUBmZmZmZmYGQFyPwvUoXAdAUrgehetRCEBI4XoUrkcJQDwK16NwPQpAMjMzMzMzC0AoXI\u002fC9SgMQB6F61G4Hg1AFK5H4XoUDkAK16NwPQoPQAAAAAAAABBAexSuR+F6EED2KFyPwvUQQHA9CtejcBFA61G4HoXrEUBmZmZmZmYSQOF6FK5H4RJAXI\u002fC9ShcE0DXo3A9CtcTQFK4HoXrURRAzMzMzMzMFEBH4XoUrkcVQML1KFyPwhVAPQrXo3A ...

# %% [markdown]
# ## Pulse-shape independence — CW field
#
# Beer–Lambert attenuation depends only on frequency and optical depth,
# not on pulse shape.  A continuous-wave (CW) field ramped on at $t = 0$ reaches
# a steady-state transmitted amplitude determined solely by $Ng$ once the
# transient has decayed.  This is the same $e^{-\alpha/2}$ factor seen above.
#
# With decay present the transient ring-on settles in a time $\sim 1/\Gamma$.

# %%
mb_solve_json_cw = """
{
  "atom": {
    "decays": [{"channels": [[0, 1]], "rate": 1.0}],
    "fields": [
      {
        "coupled_levels": [[0, 1]],
        "detuning": 0.0,
        "rabi_freq": 1.0e-3,
        "rabi_freq_t_args": {"ampl": 1.0, "on": 0.0, "off": 8.0, "fwhm": 1.0},
        "rabi_freq_t_func": "ramp_onoff"
      }
    ],
    "num_states": 2
  },
  "t_min": -2.0,
  "t_max": 10.0,
  "t_steps": 100,
  "z_min": -0.2,
  "z_max": 1.2,
  "z_steps": 20,
  "interaction_strengths": [10.0],
  "savefile": "mbs-linear-absorption-cw"
}
"""

mbs_cw = mb_solve.MBSolve().from_json_str(mb_solve_json_cw)
mbs_cw.mbsolve(recalc=False);

# %%
fig = plot.field_spacetime(mbs_cw)
fig.update_layout(title="|Ω(z, t)| — CW ramp-on field, Ng = 10, Γ = 1")
fig.show(renderer='notebook_connected')
# Out:
#         <script>
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.5.0.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="106a1cc9-3de8-48d5-b24a-1a3d898f033d" class="plotly-graph-div" style="height:400px; width:700px;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("106a1cc9-3de8-48d5-b24a-1a3d898f033d")) {                    Plotly.newPlot(                        "106a1cc9-3de8-48d5-b24a-1a3d898f033d",                        [{"colorbar":{"title":{"text":"|Ω| (γ)"}},"colorscale":[[0.0,"rgb(247,251,255)"],[0.125,"rgb(222,235,247)"],[0.25,"rgb(198,219,239)"],[0.375,"rgb(158,202,225)"],[0.5,"rgb(107,174,214)"],[0.625,"rgb(66,146,198)"],[0.75,"rgb(33,113,181)"],[0.875,"rgb(8,81,156)"],[1.0,"rgb(8,48,107)"]],
Omega_cw_z = np.abs(mbs_cw.Omegas_zt[0, :, i_t5])

# Reference amplitude before the medium (z < 0, vacuum region)
Omega_0 = Omega_cw_z[0]   # at z = z_min = -0.2

# Beer-Lambert curve: Ω(z) = Ω₀ exp(−Ng z/Γ) inside medium [0, 1]
# outside [0, 1] the density is zero so amplitude is constant
Ng_val = 10.0
Gamma = 1.0
z_arr = mbs_cw.zlist
beer_lambert = Omega_0 * np.exp(-Ng_val / Gamma * np.clip(z_arr, 0.0, 1.0))

fig = go.Figure()
fig.add_trace(go.Scatter(
    x=z_arr, y=Omega_cw_z,
    mode='lines', name='simulation (CW steady state)',
))
fig.add_trace(go.Scatter(
    x=z_arr, y=beer_lambert,
    mode='lines', name='Beer–Lambert: Ω₀ exp(−Ng z/Γ)',
    line=dict(dash='dash'),
))
fig.update_layout(
    title='CW steady-state spatial profile vs Beer–Lambert (Ng = 10, Γ = 1)',
    xaxis_title='z',
    yaxis_title='|Ω| (γ)',
    yaxis_type='log',
    template='maxwellbloch',
    width=700,
    height=400,
)
fig.show(renderer='notebook_connected')
# Out:
#         <script>
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.5.0.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="fa7ef330-d478-4587-9629-40ee1269df60" class="plotly-graph-div" style="height:400px; width:700px;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("fa7ef330-d478-4587-9629-40ee1269df60")) {                    Plotly.newPlot(                        "fa7ef330-d478-4587-9629-40ee1269df60",                        [{"mode":"lines","name":"simulation (CW steady state)","x":{"dtype":"f8","bdata":"mpmZmZmZyb+kcD0K16PAv7wehetRuK6\u002fYBSuR+F6hD94FK5H4Xq0PzIzMzMzM8M\u002fJlyPwvUozD+OwvUoXI\u002fSPwnXo3A9Ctc\u002fg+tRuB6F2z\u002f\u002f\u002f\u002f\u002f\u002f\u002f\u002f\u002ffPzwK16NwPeI\u002fehSuR+F65D+4HoXrUbjmP\u002fQoXI\u002fC9eg\u002fMjMzMzMz6z9wPQrXo3DtP65H4XoUru8\u002f9Shcj8L18D8UrkfhehTyPzMzMzMzM\u002fM\u002f"},"y":{"dtype":"f8","bdata":"w3GLtmW8eT\u002fDcYu2Zbx5P8Nxi7ZlvHk\u002fplbch3a6cD\u002fsq8gRpq5hP6C9zRW2TlI\u002f5VXcHA\u002fpQj88mZRYJIczPyHLXRFAKiQ\u002fANq9hJ\u002fSFD\u002f\u002fYCrXeIAFP4gipYoENPY+yu2U+VPt5j7XIa0v+azXPmLYL2\u002fhccg+4rgc0F0\u002fuT7lPY6n4BSqPlhgRqT78Jo+WGBGpPvwmj5YYEak+\u002fCaPlhgRqT78Jo+"},"type":"scatter"},{"line":{"dash":"dash"},"mode":"lines","name":"Beer–Lambert: Ω₀ exp(−Ng z\u002fΓ)","x":{"dtype":"f8","bdata":"mpmZmZmZyb+kcD0K16PAv7wehetRuK6\u002fYBSuR+F6hD94FK5H4Xq0PzIzMzMzM8M\u002fJlyPwvUozD+OwvUoXI\u002fSPwnXo3A9Ctc\u002fg+tRuB6F2z\u002f\u002f\u002f\u002f\u002f\u002f\u002f\u002f\u002ffPzwK16NwPeI\u002fehSuR+F65D+4HoXrUbjmP\u002fQoXI\u002fC9eg\u002fMjMzMzMz6z9wPQrXo3DtP65H4XoUru8\u002f9Shcj8L18D8UrkfhehTyPzMzMzMzM\u002fM\u002f"},"y":{"dtype":"f8","bdata":"w3GLtmW8eT\u002fDcYu2Zbx5P8Nxi7ZlvHk\u002ftpe8rG1Jdz8Qb+QptyBnP8yi+tRH+FY\u002f4VmNMR\u002fQRj8aTQTEPKg2P8RKnxGggCY\u002f17x0oEhZFj\u002fDMXD3NTIGP9znUJ5nC\u002fY+IVuoHd3k5T7H1dj+lb7VPjcDFMyRmMU+NYVZENBytT4ajHVXUE2lPhRx\u002fy0SKJU+mbEQ6akkkz6ZsRDpqSSTPpmxEOmpJJM+"},"type":"scatter"}],                        {"template":{"layout":{"colorscale":{"diverging":[[0.0,"rgb(103,0,31)"],[0.1,"rgb(178,24,43)"],[0.2,"rgb(214,96,77)"],[0.3,"rgb(244,165,130)"],[0.4,"rgb(253,219,199)"],[0.5,"rgb(247,247,247)"],[0.6,"rgb(209,229,240)"],[0.7,"rgb(146,197,222)"],[0.8,"rgb(67,147,195)"],[0.9,"rgb(33,102,172)"],[1.0,"rgb(5,48,97)"]],"sequential":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]},"colorway":["#4477AA","#EE6677","#228833","#CCBB44","#66CCEE","#AA3377","#BBBBBB"],"font":{"family":"sans-serif","size":13},"legend":{"bgcolor":"rgba(255,255,255,0.8)","bordercolor":"#cccccc","borderwidth":1},"margin":{"b":60,"l":60,"r":20,"t":50},"paper_bgcolor":"white","plot_bgcolor":"white","xaxis":{"gridcolor":"#e0e0e0","linecolor":"#888888","mirror":false,"showgrid":true,"showline":true,"ticks":"inside","zeroline":true,"zerolinecolor":"#aaaaaa","zerolinewidth":1},"yaxis":{"gridcolor":"#e0e0e0","linecolor":"#888888","mirror":false,"showgrid":true,"showline":true,"ticks":"inside","zeroline":true,"zerolinecolor":"#aaaaaa","zerolinewidth":1}}},"yaxis":{"title":{"text":"|Ω| (γ)"},"type":"log"},"title":{"text":"CW steady-state spatial profile vs Beer–Lambert (Ng = 10, Γ = 1)"},"xaxis":{"title":{"text":"z"}},"width":700,"height":400},                        {"responsive": true}                    ).then(function(){
#
# var gd = document.getElementById('fa7ef330-d478-4587-9629-40ee1269df60');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };            </script>        </div>

# %% [markdown]
# ## Summary
#
# - In the **weak-field limit** ($\Omega_0 \ll \Gamma$) the Maxwell–Bloch equations
#   reduce to the Beer–Lambert law: amplitude decays exponentially with $Ng$.
# - Without spontaneous decay the atoms respond coherently; the medium acts as a
#   resonant absorber but also re-emits energy, producing a **free induction decay**
#   tail after the pulse.
# - Adding decay at rate $\Gamma$ damps the coherence on timescale $T_2 = 2/\Gamma$.
#   Once $T_2 \lesssim \tau_\text{pulse}$ the transmission matches the steady-state
#   Beer–Lambert prediction.
# - The steady-state attenuation is **pulse-shape independent**: both Gaussian and
#   CW fields with the same $Ng$ reach the same transmitted amplitude once transients
#   have decayed.
#
# The nonlinear regime — where the field is strong enough to saturate the transition
# and the area theorem governs propagation — is covered in the
# Area Theorem and SIT Solitons notebooks.
