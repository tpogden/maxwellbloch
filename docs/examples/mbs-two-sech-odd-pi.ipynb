# %% [markdown]
# # Two-Level: Odd-π Sech Pulses — Area Theorem
#
# The McCall–Hahn area theorem governs how the pulse area
# $\mathcal{A}(z) = \int_{-\infty}^{\infty} \Omega(z,t)\,dt$
# evolves as a pulse propagates through a resonant two-level absorber.
# For a purely absorbing medium the area satisfies
#
# $$
# \frac{d\mathcal{A}}{dz} = -\frac{\alpha}{2}\sin\mathcal{A},
# $$
#
# where $\alpha$ is the resonant absorption coefficient.
# The stable fixed points are even multiples of $\pi$ (including zero);
# odd multiples of $\pi$ are **unstable** saddle points.
#
# | Input area | Fate |
# |---|---|
# | $1\pi$ | absorbed toward $0\pi$ |
# | $3\pi$ | breaks into one $2\pi$ soliton (residual $1\pi$ absorbed) |
# | $5\pi$ | breaks into two $2\pi$ solitons (residual $1\pi$ absorbed) |
#
# This notebook demonstrates all three cases using identical sech-pulse
# envelopes that differ only in their initial area.

# %% [markdown]
# ## Parameters
#
# The sech pulse $\Omega(t) = \Omega_0\,\text{sech}(t/t_w)$ has pulse area
# $\mathcal{A} = \pi\,\Omega_0\,t_w$.
# Setting `n_pi` in the JSON config scales $\Omega_0$ so that the area is
# exactly $n\pi$ at $z = z_\mathrm{min}$.
#
# The medium optical depth is set by `interaction_strengths`. Here we use
# $C = 10$ (optically thick) so that the soliton structure is pronounced.
#
# Spontaneous decay is included at rate $\gamma = 1.0\,\gamma_0$ (the
# natural unit), giving $T_2 = 1/(\pi\gamma_0) \approx 0.318\,\gamma_0^{-1}$.
# Without decay the residual sub-$2\pi$ energy rings indefinitely and the
# area does not converge cleanly. With decay it dissipates into the ground
# state. The soliton itself is unaffected because the pulse FWHM
# $(0.1\,\gamma_0^{-1}) \approx T_2/3$, so the pulse is short enough for
# coherent SIT to operate.

# %%
import numpy as np
from maxwellbloch import mb_solve, plot

FWHM = 0.1  # sech pulse FWHM in γ⁻¹
T2 = 1.0 / (np.pi * 1.0)  # coherence time for rate=1.0: T₂ = 1/(π·rate)
print(f"Pulse FWHM = {FWHM:.2f} γ⁻¹")
print(f"T₂ (rate=1.0) = {T2:.4f} γ⁻¹")
print(f"FWHM / T₂ = {FWHM / T2:.3f}  (must be ≪ 1 for clean SIT)")
# Out:
# Pulse FWHM = 0.10 γ⁻¹
# T₂ (rate=1.0) = 0.3183 γ⁻¹
# FWHM / T₂ = 0.314  (must be ≪ 1 for clean SIT)

# %% [markdown]
# ## 1π pulse — absorbed
#
# A pulse with area below $2\pi$ cannot form a self-induced transparency
# soliton. The area decays monotonically to zero: the pulse is absorbed
# by the medium.

# %%
mb_solve_json_1pi = """
{
  "atom": {
    "decays": [{"channels": [[0, 1]], "rate": 1.0}],
    "fields": [
      {
        "coupled_levels": [[0, 1]],
        "rabi_freq_t_args": {"n_pi": 1.0, "centre": 0.0, "fwhm": 0.1},
        "rabi_freq_t_func": "sech"
      }
    ],
    "num_states": 2
  },
  "t_min": -0.5,
  "t_max": 3.0,
  "t_steps": 700,
  "z_min": -0.5,
  "z_max": 1.5,
  "z_steps": 100,
  "interaction_strengths": [10.0],
  "savefile": "mbs-two-sech-1pi-decay"
}
"""

mbs_1pi = mb_solve.MBSolve().from_json_str(mb_solve_json_1pi)
print(f"Input area: {np.trapezoid(mbs_1pi.Omegas_zt[0, 0, :].real, mbs_1pi.tlist) / np.pi:.4f} π")
mbs_1pi.mbsolve(recalc=False);
# Out:
# Input area: 1.0000 π
#   z-step 10/100 (10%)
# /Users/tpo/repos/maxwellbloch/.venv/lib/python3.14/site-packages/qutip/solver/solver_base.py:598: FutureWarning: e_ops will be keyword only from qutip 5.3 for all solver
#   warnings.warn(
#   z-step 20/100 (20%)
#   z-step 30/100 (30%)
#   z-step 40/100 (40%)
#   z-step 50/100 (50%)
#   z-step 60/100 (60%)
#   z-step 70/100 (70%)
#   z-step 80/100 (80%)
#   z-step 90/100 (90%)
# Saving MBSolve to mbs-two-sech-1pi-decay.qu

# %%
fig = plot.field_spacetime(mbs_1pi)
fig.update_layout(title="|Ω(z, t)| — 1π sech pulse")
fig.show(renderer='notebook_connected')
# Out:
#         <script>
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.5.0.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="e11926d7-fb1f-4238-8212-8b6149b9f82d" class="plotly-graph-div" style="height:400px; width:700px;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("e11926d7-fb1f-4238-8212-8b6149b9f82d")) {                    Plotly.newPlot(                        "e11926d7-fb1f-4238-8212-8b6149b9f82d",                        [{"colorbar":{"title":{"text":"|Ω| (γ)"}},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"x":{"dtype":"f8","bdata":"AAAAAAAA4L+uR+F6FK7fv1yPwvUoXN+\u002fCtejcD0K37+4HoXrUbjev2ZmZmZmZt6\u002fFK5H4XoU3r\u002fC9Shcj8Ldv3E9CtejcN2\u002fH4XrUbge3b\u002fNzMzMzMzcv3sUrkfhety\u002fKVyPwvUo3L\u002fXo3A9Ctfbv4XrUbgehdu\u002fMzMzMzMz27\u002fhehSuR+Hav4\u002fC9Shcj9q\u002fPgrXo3A92r\u002fsUbgehevZv5qZmZmZmdm\u002fSOF6FK5H2b\u002f2KFyPwvXYv6RwPQrXo9i\u002fUrgehetR2L8AAAAAAADYv65H4XoUrte\u002fXI\u002fC9Shc178K16NwPQrXv7gehetRuNa\u002fZmZmZmZm1r8UrkfhehTWv8L1KFyPwtW\u002fcD0K16Nw1b8ehetRuB7Vv8zMzMzMzNS\u002fexSuR+F61L8pXI\u002fC9SjUv9ejcD0K19O\u002fhetRuB6F078zMzMzMzPTv+F6FK5H4dK\u002fkML1KFyP0r8+CtejcD3Sv+xRuB6F69G\u002fmpmZmZmZ0b9I4XoUrkfRv\u002fYoXI\u002fC9dC\u002fpHA9Ctej0L9SuB6F61HQvwAAAAAAANC\u002fXI\u002fC9Shcz7+4HoXrUbjOvxSuR+F6FM6\u002fcD0K16Nwzb\u002fMzMzMzMzMvyhcj8L1KMy\u002fhOtRuB6Fy7\u002fiehSuR+HKvz4K16NwPcq\u002fmpmZmZmZyb\u002f2KFyPwvXIv1K4HoXrUci\u002frkfhehSux78K16NwPQrHv2ZmZmZmZsa\u002fwvUoXI\u002fCxb8eh
08Voq1B9uU\u002fTxWirUH25T9PFaKtQfblP08Voq1B9uU\u002fTxWirUH25T9PFaKtQfblP08Voq1B9uU\u002fTxWirUH25T9PFaKtQfblP08Voq1B9uU\u002fTxWirUH25T9PFaKtQfblP08Voq1B9uU\u002fTxWirUH25T9PFaKtQfblPw=="},"type":"scatter"}],                        {"height":400,"template":{"layout":{"colorscale":{"diverging":[[0.0,"rgb(103,0,31)"],[0.1,"rgb(178,24,43)"],[0.2,"rgb(214,96,77)"],[0.3,"rgb(244,165,130)"],[0.4,"rgb(253,219,199)"],[0.5,"rgb(247,247,247)"],[0.6,"rgb(209,229,240)"],[0.7,"rgb(146,197,222)"],[0.8,"rgb(67,147,195)"],[0.9,"rgb(33,102,172)"],[1.0,"rgb(5,48,97)"]],"sequential":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#316 ...
#
# var gd = document.getElementById('cd233214-0e4a-41e8-aa27-a625b34212bc');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };            </script>        </div>

# %% [markdown]
# ## 3π pulse — one 2π soliton emitted
#
# The $3\pi$ input is an unstable fixed point of the area equation.
# Any perturbation (including numerical discretisation) tips it toward
# the nearest stable attractor. The lower $2\pi$ attractor 'wins': the
# pulse emits a single SIT soliton and the residual $1\pi$ component is
# absorbed.

# %%
mb_solve_json_3pi = """
{
  "atom": {
    "decays": [{"channels": [[0, 1]], "rate": 1.0}],
    "fields": [
      {
        "coupled_levels": [[0, 1]],
        "rabi_freq_t_args": {"n_pi": 3.0, "centre": 0.0, "fwhm": 0.1},
        "rabi_freq_t_func": "sech"
      }
    ],
    "num_states": 2
  },
  "t_min": -0.5,
  "t_max": 3.0,
  "t_steps": 700,
  "z_min": -0.5,
  "z_max": 1.5,
  "z_steps": 100,
  "interaction_strengths": [10.0],
  "savefile": "mbs-two-sech-3pi-decay"
}
"""

mbs_3pi = mb_solve.MBSolve().from_json_str(mb_solve_json_3pi)
print(f"Input area: {np.trapezoid(mbs_3pi.Omegas_zt[0, 0, :].real, mbs_3pi.tlist) / np.pi:.4f} π")
mbs_3pi.mbsolve(recalc=False);
# Out:
# Input area: 3.0000 π
#   z-step 10/100 (10%)
# /Users/tpo/repos/maxwellbloch/.venv/lib/python3.14/site-packages/qutip/solver/solver_base.py:598: FutureWarning: e_ops will be keyword only from qutip 5.3 for all solver
#   warnings.warn(
#   z-step 20/100 (20%)
#   z-step 30/100 (30%)
#   z-step 40/100 (40%)
#   z-step 50/100 (50%)
#   z-step 60/100 (60%)
#   z-step 70/100 (70%)
#   z-step 80/100 (80%)
#   z-step 90/100 (90%)
# Saving MBSolve to mbs-two-sech-3pi-decay.qu

# %%
fig = plot.field_spacetime(mbs_3pi)
fig.update_layout(title="|Ω(z, t)| — 3π sech pulse")
fig.show(renderer='notebook_connected')
# Out:
#         <script>
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.5.0.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="7da814a4-f334-4958-b31f-34b01fd69053" class="plotly-graph-div" style="height:400px; width:700px;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("7da814a4-f334-4958-b31f-34b01fd69053")) {                    Plotly.newPlot(                        "7da814a4-f334-4958-b31f-34b01fd69053",                        [{"colorbar":{"title":{"text":"|Ω| (γ)"}},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],
udCWQKYHQOoVfZyWjQdAmO15tcR1B0D\u002fQD4+oV4HQGVEVzRHSAdACSIJNlYyB0DEdX9eFh0HQIayXVJDCAdAKiogJqvzBkCknfi0cN8GQPTmANeGywZA+ddjUo23BkCPG9PEM6MGQD1mWVWEjwZAdoj5w2V7BkB6LIb5OWcGQI4ZTiUaUwZA8rTpucY+BkANss23QCoGQGgBEw8PFgZAyVbQjdgABkDE2jO2xOwFQBRtkhwS2AVAu1fWeo\u002fCBUAggvOaOq4FQHzRyeSNmQVAgZ8sijaEBUAAFDNjkm4FQM0h4843WgVAl9DXe2VFBUC7iXT+JDAFQIQn5zh4GgVA1wAo4\u002fEEBUAfZWsRZPAEQFCjse2x2wRAgIx\..."},"type":"scatter"}],                        {"height":400,"template":{"layout":{"colorscale":{"diverging":[[0.0,"rgb(103,0,31)"],[0.1,"rgb(178,24,43)"],[0.2,"rgb(214,96,77)"],[0.3,"rgb(244,165,130)"],[0.4,"rgb(253,219,199)"],[0.5,"rgb(247,247,247)"],[0.6,"rgb(209,229,240)"],[0.7,"rgb(146,197,222)"],[0.8,"rgb(67,147,195)"],[0.9,"rgb(33,102,172)"],[1.0,"rgb(5,48,97)"]],"sequential":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]},"colorway":["#4477AA","#EE6677","#228833","#CCBB44","#66CCEE","#AA3377","#BBBBBB"],"font":{"family":"sans-serif","size":13},"legend":{"bgcolor":"rgba(255,255,255,0.8)","bordercolor":"#cccccc","borderwidth":1},"margin":{"b":60,"l":60,"r":20,"t":50},"paper_bgcolor":"white","plot_bgcolor":"white","xaxis":{"gridcolor":"#e0e0e0","linecolor":"#888888","mirror":false,"showgrid":true,"showline":true,"ticks":"inside","zeroline":true,"zerolinecolor":"#aaaaaa","zerolinewidth":1},"yaxis":{"gridcolor":"#e0e0e0","linecolor":" ...
#
# var gd = document.getElementById('9b068297-da61-4e73-9227-cd7096a8b174');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };            </script>        </div>

# %% [markdown]
# ## 5π pulse — two 2π solitons emitted
#
# The $5\pi$ pulse breaks into **two** $2\pi$ solitons. Each soliton has
# a different width (and therefore a different group velocity — solitons
# with larger area travel faster), so they separate as they propagate
# through the medium.

# %%
mb_solve_json_5pi = """
{
  "atom": {
    "decays": [{"channels": [[0, 1]], "rate": 1.0}],
    "fields": [
      {
        "coupled_levels": [[0, 1]],
        "rabi_freq_t_args": {"n_pi": 5.0, "centre": 0.0, "fwhm": 0.1},
        "rabi_freq_t_func": "sech"
      }
    ],
    "num_states": 2
  },
  "t_min": -0.5,
  "t_max": 3.0,
  "t_steps": 700,
  "z_min": -0.5,
  "z_max": 1.5,
  "z_steps": 100,
  "interaction_strengths": [10.0],
  "savefile": "mbs-two-sech-5pi-decay"
}
"""

mbs_5pi = mb_solve.MBSolve().from_json_str(mb_solve_json_5pi)
print(f"Input area: {np.trapezoid(mbs_5pi.Omegas_zt[0, 0, :].real, mbs_5pi.tlist) / np.pi:.4f} π")
mbs_5pi.mbsolve(recalc=False);
# Out:
# Input area: 5.0000 π
#   z-step 10/100 (10%)
# /Users/tpo/repos/maxwellbloch/.venv/lib/python3.14/site-packages/qutip/solver/solver_base.py:598: FutureWarning: e_ops will be keyword only from qutip 5.3 for all solver
#   warnings.warn(
#   z-step 20/100 (20%)
#   z-step 30/100 (30%)
#   z-step 40/100 (40%)
#   z-step 50/100 (50%)
#   z-step 60/100 (60%)
#   z-step 70/100 (70%)
#   z-step 80/100 (80%)
#   z-step 90/100 (90%)
# Saving MBSolve to mbs-two-sech-5pi-decay.qu

# %%
fig = plot.field_spacetime(mbs_5pi)
fig.update_layout(title="|Ω(z, t)| — 5π sech pulse")
fig.show(renderer='notebook_connected')
# Out:
#         <script>
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.5.0.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="75b5e8cc-8687-4ea1-aa4c-d1a31a1da66c" class="plotly-graph-div" style="height:400px; width:700px;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("75b5e8cc-8687-4ea1-aa4c-d1a31a1da66c")) {                    Plotly.newPlot(                        "75b5e8cc-8687-4ea1-aa4c-d1a31a1da66c",                        [{"colorbar":{"title":{"text":"|Ω| (γ)"}},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"x":{"dtype":"f8","bdata":"AAAAAAAA4L+uR+F6FK7fv1yPwvUoXN+\u002fCtejcD0K37+4HoXrUbjev2ZmZmZmZt6\u002fFK5H4XoU3r\u002fC9Shcj8Ldv3E9CtejcN2\u002fH4XrUbge3b\u002fNzMzMzMzcv3sUrkfhety\u002fKVyPwvUo3L\u002fXo3A9Ctfbv4XrUbgehdu\u002fMzMzMzMz27\u002fhehSuR+Hav4\u002fC9Shcj9q\u002fPgrXo3A92r\u002fsUbgehevZv5qZmZmZmdm\u002fSOF6FK5H2b\u002f2KFyPwvXYv6RwPQrXo9i\u002fUrgehetR2L8AAAAAAADYv65H4XoUrte\u002fXI\u002fC9Shc178K16NwPQrXv7gehetRuNa\u002fZmZmZmZm1r8UrkfhehTWv8L1KFyPwtW\u002fcD0K16Nw1b8ehetRuB7Vv8zMzMzMzNS\u002fexSuR+F61L8pXI\u002fC9SjUv9ejcD0K19O\u002fhetRuB6F078zMzMzMzPTv+F6FK5H4dK\u002fkML1KFyP0r8+CtejcD3Sv+xRuB6F69G\u002fmpmZmZmZ0b9I4XoUrkfRv\u002fYoXI\u002fC9dC\u002fpHA9Ctej0L9SuB6F61HQvwAAAAAAANC\u002fXI\u002fC9Shcz7+4HoXrUbjOvxSuR+F6FM6\u002fcD0K16Nwzb\u002fMzMzMzMzMvyhcj8L1KMy\u002fhOtRuB6Fy7\u002fiehSuR+HKvz4K16NwPcq\u002fmpmZmZmZyb\u002f2KFyPwvXIv1K4HoXrUci\u002frkfhehSux78K16NwPQrHv2ZmZmZmZsa\u002fwvUoXI\u002fCxb8ehetRuB7Fv3oUrkfhesS\u002f1qNwPQrXw78yMzMzMzPDv5DC9Shcj8K\u002f7FG4HoXrwb9I4XoUrkfBv6RwPQrXo8C\u002fAAAAAAAAwL+4HoXrUbi+v3A9CtejcL2\u002fKFyPwvUovL\u002fgehSuR+G6v5iZmZmZmbm\u002fULgehetRuL8I16NwPQq3v8D1K
P3sUrkfhevQ\u002fzczMzMzM9D8fhetRuB71P3E9CtejcPU\u002fw\u002fUoXI\u002fC9T8VrkfhehT2P2dmZmZmZvY\u002fuB6F61G49j8K16NwPQr3P1yPwvUoXPc\u002frkfhehSu9z8AAAAAAAD4Pw=="},"y":{"dtype":"f8","bdata":"esriZ\u002f7\u002fE0B6yuJn\u002fv8TQHrK4mf+\u002fxNAesriZ\u002f7\u002fE0B6yuJn\u002fv8TQHrK4mf+\u002fxNAesriZ\u002f7\u002fE0B6yuJn\u002fv8TQHrK4mf+\u002fxNAesriZ\u002f7\u002fE0B6yuJn\u002fv8TQHrK4mf+\u002fxNAesriZ\u002f7\u002fE0B6yuJn\u002fv8TQHrK4mf+\u002fxNAesriZ\u002f7\u002fE0B6yuJn\u002fv8TQHrK4mf+\u002fxNAesriZ\u002f7\u002fE0B6yuJn\u002fv8TQHrK4mf+\u002fxNAesriZ\u002f7\u002fE0B6yuJn\u002fv8TQHrK4mf+\u002fxNAesriZ\u002f7\u002fE0B6yuJn\u002fv8TQHM\u002fSieC7hNAit0Yu3bgE0Bn2fdePNMTQNLcv8NaxhNAS9x5O7S5E0CCIQ6lUK0TQLf178ULoRNAewwbjiGVE0C3QuDtZIkTQLkH5uXUfRNAVPqWWWpyE0AbjmKKFWcTQAtMgAj1WxNArVswG\u002f9QE0CoA8Ix8UUTQD1a4hX8OhNAdYJJiikwE0Ao8zBoHyUTQJ4eVbFqGhNAw5XaQWsPE0DBvDmQpQQTQJrFFHzM+RJA\\"},"type":"scatter"}],                        {"height":400,"template":{"layout":{"colorscale":{"diverging":[[0.0,"rgb(103,0,31)"],[0.1,"rgb(178,24,43)"],[0.2,"rgb(214,96,77)"],[0.3,"rgb(244,165,130)"],[0.4,"rgb(253,219,199)"],[0.5,"rgb(247,247,247)"],[0.6,"rgb(209,229,240)"],[0.7,"rgb(146,197,222)"],[0.8,"rgb(67,147,195)"],[0.9,"rgb(33,102,172)"],[1.0,"rgb(5,48,97)"]],"sequential":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]},"colorway":["#4477AA","#EE6677","#228833","#CCBB44","#66CCEE","#AA ...
#
# var gd = document.getElementById('86617444-2be1-49b3-9eea-ff2b49593ac5');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };            </script>        </div>

# %% [markdown]
# ## Summary
#
# The area theorem is confirmed in all three cases:
#
# - **1π**: area decays monotonically to 0 — the pulse is absorbed.
# - **3π**: area first rises slightly as the soliton forms, then the soliton
#   exits the medium at $2\pi$ while the residual component is absorbed.
# - **5π**: two $2\pi$ solitons are clearly visible in the space-time plot;
#   the faster (narrower) soliton separates from the slower one, and the area
#   converges to $4\pi$ at the exit.
#
# The general rule: an $n\pi$ pulse with $n$ odd exits with $(n-1)$ solitons,
# each carrying $2\pi$ area.
#
# ## References
#
# 1. S. L. McCall and E. L. Hahn, *Self-Induced Transparency by Pulsed Coherent
#    Light*, PRL **18**, 908 (1967). Original area theorem.
# 2. S. L. McCall and E. L. Hahn, *Self-Induced Transparency*,
#    Phys. Rev. **183**, 457 (1969). Full theory.
