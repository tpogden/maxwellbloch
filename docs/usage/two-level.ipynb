# %%
import matplotlib.pyplot as plt

# %matplotlib inline
import numpy as np

from maxwellbloch import plot

# %% [markdown]
# # Getting Started with the Two-Level Atom

# %% [markdown]
# The first model we'll consider is a medium of two-level atoms, coupled by a weak pulse.
#
# ```
# ____ |1>
#  |
#  | Ω
#  |
# ____ |0>
# ```
#
# We'll need to define a field, and the two-level atom for the field to address.

# %% [markdown]
# ## Defining the Field and Atom

# %%
from maxwellbloch import field, ob_atom

# %% [markdown]
# First we'll define the field. The quantity we care about is the input Rabi frequency as a function of time, $\Omega(t)$. Let's say our input pulse has a max $\Omega_0 = 2\pi \cdot 0.001 \mathrm{~ MHz}$, and is a Gaussian with a full-width at half-maximum (FWHM) of $1 \mathrm{~ \mu s}$.

# %%
the_field = field.Field(
    coupled_levels=[[0, 1]],
    rabi_freq=1.0e-3,  # [2π MHz]
    rabi_freq_t_func="gaussian",
    rabi_freq_t_args={
        "ampl": 1.0,
        "centre": 0.0,  # [μs]
        "fwhm": 1.0,
    },  # [μs]
)

# %% [markdown]
# The first property `coupled_levels` is a list of pairs to be coupled by the field. In this case we only have two levels, indexed `0` (the ground state) and `1` (the excited state). The properties `rabi_freq`, `rabi_freq_t_func` and `rabi_freq_t_args` together define the field profile entering the medium. What does the profile look like in this case?

# %%
tlist = np.linspace(-2, 10, 100)
fig = plot.field_profile(the_field, tlist)
fig.show(renderer='notebook_connected')
# Out:
#         <script>
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.5.0.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="2352477c-d6b0-4581-98d1-19329ed50269" class="plotly-graph-div" style="height:400px; width:700px;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("2352477c-d6b0-4581-98d1-19329ed50269")) {                    Plotly.newPlot(                        "2352477c-d6b0-4581-98d1-19329ed50269",                        [{"fill":"tozeroy","fillcolor":"rgba(33, 113, 181, 0.2)","line":{"color":"#2171B5"},"mode":"lines","showlegend":false,"x":{"dtype":"f8","bdata":"AAAAAAAAAMAQPvjggw\u002f+vx988MEHH\u002fy\u002fLrrooosu+r8++OCDDz74v0422WSTTfa\u002fXXTRRRdd9L9ssskmm2zyv3zwwQcffPC\u002fGF100UUX7b822WSTTTbpv1RVVVVVVeW\u002fdNFFF1104b8om2yyySbbv2STTTbZZNO\u002fQBdddNFFx78AH3zwwQevvwAffPDBB68\u002fQBdddNFFxz9ok0022WTTPyibbLLJJts\u002fdNFFF1104T9YVVVVVVXlPzjZZJNNNuk\u002fGF100UUX7T988MEHH3zwP2yyySabbPI\u002fXnTRRRdd9D9ONtlkk032Pz744IMPPvg\u002fMLrooosu+j8gfPDBBx\u002f8PxA++OCDD\u002f4\..."},"y":{"dtype":"f8","bdata":"\u002fqnx0k1iUD7MGhxobypuPr\u002fnhWbvmIk+yJMHWHsFpD6FX5wqnt68Ppl6yqV\u002fL9M+iaUffzOB5z6KRZI3C4v6PlJ9vdkOoQs\u002f7Uf5NGaCGj\u002fniwGg5nEnP3W\u002fyQTHHDM\u002fcZnjnRS5PD+\u002f1Ko39uRDP63ymhgTZ0k\u002fF5+0J+3lTT95KKxZzjdQP3korFnON1A\u002fF5+0J+3lTT+q8poYE2dJP7\u002fUqjf25EM\u002fcZnjnRS5PD9sv8kExxwzP+CLAaDmcSc\u002f7Uf5NGaCGj9Sfb3ZDqELP4pFkjcLi\u002fo+d6UffzOB5z6Zesqlfy\u002fTPoVfnCqe3rw+tJMHWHsFpD6l54Vm75iJPswaHGhvKm4+\u002fqnx0k1iUD6Pw6uQpWcwPvZyLMb7Rw4+EaRkDMfC6T1rdx3nWzPEPZaw12XHM509wmzwC8J0cz1mkRSwm+VHPdykm6kKDhs9C5GbRss77DwM4gHwiii7PJgHAGWDFIg8ALAbjCauUzzHPBP72qYdPLAuNgIOl+Q7NIMhc6JbqjsvXuH+AhpvO2RsDSrv6TA7\u002f5DY5vj08Dqyh9fqDlevOklR+rIUsmo61ExgXtb1JDoDBgPOzFbeORhuIj0+PZQ5zMwhxPXjSDn6GVftMTf8ONON3t1+e604g31PNFFlXDhC1vfplzUJOGf6JSAhobQ3DVSmxBQfXzdHQ0vpWaMFN8VL9yEfvKs2A6rx0k1iUDaWd4UWvdfxNb6fyVQ36ZE135XIZqKSMDUl+\u002fg4AEXMNM6j5HduOWY0Zy1ludYaADSOrqW2tYOVM6XZAcIUfioz0IESzOURvjIs7yjBwXVPMlkGA87MVt4xS5mv2wj4ajEFjdXO7hj2MIHsFoBxsIAwQV8\u002f16c8BzCPpDzddtKNL9us9Gy0oxEvSALC6gQ8ky7pq1n9J1UTLs2fyVQ36ZEtOIYfOVWXDi2GBgBlgxSILKsJzdzLeAEsmtvSidRedyvP0ZPZhNDsKnF\u002fKJuiX2Aq0lgFIf4m0Sm+E5tP749AKQSO3t1+e60okv+JXAowGCj2tXZyi0qCJ2MQxg\u002f1f+km3anx0k1iUCY="},"type":"scatter"}],                        {"height":400,"template":{"layout":{"colorscale":{"diverging":[[0.0,"rgb(103,0,31)"],[0.1,"rgb(178,24,43)"],[0.2,"rgb(214,96,77)"],[0.3,"rgb(244,165,130)"],[0.4,"rgb(253,219,199)"],[0.5,"rgb(247,247,247)"],[0.6,"rgb(209,229,240)"],[0.7,"rgb(146,197,222)"],[0.8,"rgb(67,147,195)"],[0.9,"rgb(33,102,172)"],[1.0,"rgb(5,48,97)"]],"sequential":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]},"colorway":["#4477AA","#EE6677","#228833","#CCBB44","#66CCEE","#AA3377","#BBBBBB"],"font":{"family":"sans-serif","size":13},"legend":{"bgcolor":"rgba(255,255,255,0.8)","bordercolor":"#cccccc","borderwidth":1},"margin":{"b":60,"l":60,"r":20,"t":50},"paper_bgcolor":"white","plot_bgcolor":"white","xaxis":{"gridcolor":"#e0e0e0","linecolor":"#888888","mirror":false,"showgrid":true,"showline":true,"ticks":"inside","zeroline":true,"zerolinecolor":"#aaaaaa","zerolinewidth":1},"yaxis":{"gridcolor":"#e0e0e0","linecolor":"#888888","mirror":false,"showgrid":true,"showline":true,"ticks":"inside","zeroline":true,"zerolinecolor":"#aaaaaa","zerolinewidth":1}}},"title":{"text":"|Ω(t)| — input profile"},"width":700,"xaxis":{"title":{"text":"t"}},"yaxis":{"title":{"text":"|Ω|"}}},                        {"responsive": true}                    ).then(function(){
#
# var gd = document.getElementById('2352477c-d6b0-4581-98d1-19329ed50269');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };            </script>        </div>

# %% [markdown]
# It's a Gaussian-shaped pulse, centred at $t=0$. Many more pre-defined profiles are defined in the `t_funcs` module, see [REF t_funcs doc] for details.
#
# So that's the field. Now we need to define an atom to address. Here we just need to state that `num_states=2`. The atom also takes a list of fields, in this case we've only got one, `the_field`, so we'll add that.

# %%
the_atom = ob_atom.OBAtom(
    num_states=2,
)
the_atom.fields.append(the_field)
the_atom.build_operators()

# %% [markdown]
# ## Solving the Maxwell-Bloch Equations

# %% [markdown]
# Now we have everything required to solve the problem. We just need to define the space $z$ and time $t$ dimesions we want to solve the problem over. Let's say that our medium is $1 \mathrm{~ cm}$ long and has constant number density, for example a vapour cell.

# %%
from maxwellbloch import mb_solve

# %%
mbs = mb_solve.MBSolve(
    t_min=-2.0,  # [μs]
    t_max=10.0,  # [μs]
    t_steps=100,
    z_min=-0.5,  # [cm]
    z_max=1.5,  # [cm]
    z_steps=10,
    interaction_strengths=[0.1],  # [2π MHz /cm]
)
mbs.atom = the_atom

# %% [markdown]
# Here we've set `z_min=-0.5` and `z_max=1.5` so that we can see how the pulse travels before and after it is in the medium, i.e. as it travels in vacuum.

# %% [markdown]
# ### Interaction Strength
#
# The interaction strength ($Ng$) for each field describes the strength of the coupling of the field to the medium. You can think of it as the amount of absorption per unit length of medium, so in this system it has units of $\mathrm{2\pi~MHz~/cm}$.
#
# Now we can solve the system.

# %%
Omegas_zt, states_zt = mbs.mbsolve()
# Out:
# 100%|██████████| 10/10 [00:00<00:00, 89.60z/s, Ω_max=0.00532]

# %% [markdown]
# The solver indicates progress as it goes, in 10% increments by default.

# %% [markdown]
# ## Plotting and Analysing Results

# %% [markdown]
# The solver returns two objects. `Omegas_zt` contains the complex value of each field, at each $z$-point and each $t$-point. In this case we have only one field, $50+1$ $z$-points (for 50 `z_steps`) and $100+1$ $t$-points (for 100 `t_steps`).

# %%
Omegas_zt.shape
# Out:
# (1, 11, 101)

# %% [markdown]
# `states_zt` contains the density matrix representation of the states of the atoms at each $z$-point and each $t$-point. The density matrix $\rho$ is of size $n \times n$ where $n$ is the number of states in the atom, in this case $n=2$.

# %%
states_zt.shape
# Out:
# (11, 101, 2, 2)

# %% [markdown]
# Both the Rabi frequency $\Omega$ and the density matrix $\rho$ are complex-valued, so the elements of both `Omegas_zt` and `states_zt`
# are of `np.complex` datatype.

# %%
fig = plot.field_spacetime(mbs, show_z_bounds=(0.0, 1.0))
fig.show(renderer='notebook_connected')
# Out:
#         <script>
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.5.0.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="b0c82fb5-27f0-41ce-a693-fcfe7a7376eb" class="plotly-graph-div" style="height:400px; width:700px;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("b0c82fb5-27f0-41ce-a693-fcfe7a7376eb")) {                    Plotly.newPlot(                        "b0c82fb5-27f0-41ce-a693-fcfe7a7376eb",                        [{"colorbar":{"title":{"text":"|Ω| (γ)"}},"colorscale":[[0.0,"rgb(247,251,255)"],[0.125,"rgb(222,235,247)"],[0.25,"rgb(198,219,239)"],[0.375,"rgb(158,202,225)"],[0.5,"rgb(107,174,214)"],[0.625,"rgb(66,146,198)"],[0.75,"rgb(33,113,181)"],[0.875,"rgb(8,81,156)"],[1.0,"rgb(8,48,107)"]],"x":{"dtype":"f8","bdata":"AAAAAAAAAMAUrkfhehT+vylcj8L1KPy\u002fPgrXo3A9+r9SuB6F61H4v2ZmZmZmZva\u002fexSuR+F69L+QwvUoXI\u002fyv6RwPQrXo\u002fC\u002fcD0K16Nw7b+amZmZmZnpv8T1KFyPwuW\u002f7FG4HoXr4b8oXI\u002fC9Sjcv3wUrkfhetS\u002foJmZmZmZyb+AFK5H4Xq0v4AUrkfheqQ\u002fgBSuR+F6xD\u002foUbgehevRP5iZmZmZmdk\u002fpHA9Ctej4D94FK5H4XrkP1C4HoXrUeg\u002fKFyPwvUo7D8AAAAAAADwP+xRuB6F6\u002fE\u002f1qNwPQrX8z\u002fC9Shcj8L1P65H4XoUrvc\u002fmJmZmZmZ+T+E61G4HoX7P3A9CtejcP0\u002fXI\u002fC9Shc\u002fz+kcD0K16MAQJqZmZmZmQFAkML1KFyPA
002f+tvN1oN+kmcpXsdBE3OdoJXhGhtjb4MDjOOhVbNjaX5Pv47P01Gq4USHGHnjWzmGKvIcE8Nbo+aFwiAdk0DeFwZCQTdDQRhD7Um8INNCkYSrHFXaQz4HGLtmW8OTOBVoUAgQbOMkvODy+0K2Ayturc3c8U8DE4aWhKsYd9MXMlILw8CAkxVsTASUWXkzCluI\u002fBuE8cMI8tQAMK46Iv0U6s4u5DJy+CYxVUn3WqLivH4ylbyCsusUrL3uPuqi0EX\u002fV5GRsoLTnJanJm66Ms3kZNUNlkHixM5zJ9k2iVK+KKUTom2AsrNAlTycC3gCrE+x8zvIjyKbIbKyKJ+GIpwihNUnjt0Sgy0reeeUg\u002fKJEd\u002f20FM6kneRBoGaa9EieTcYu2Zbx5JsZxi7ZlvHk+qnYXNQ1llz65ZSxAaKKzPk02uZ97bc4+PTwa0YLE5T5FmWKvIcH8PiXIawDLiBE\u002fp+luYlu+Iz9eNhjTZ4Y0P66ipJEos0M\u002f8SZylex0UT8qv5nIT5BcP7wGsO1Jk2U\u002fb3O2cZIXbj8bnvjx9F9zP2Cq6eDHCHc\u002fT7sZK4VIeT+3H9YnPJ95P\u002fUZ0nD5+Hc\u002fea+rRzu1dD\u002f4rG0g3INwP+VQcEkYUmg\u002fQjckI42IYD9t\u002f4DMAMFUP7Pbdj9tDUg\u002fw3GLtmW8OT8n3jzbgmwpP8TovmkmMBc\u002fAgj8rpyGAz\u002fJfhF0OVzuPn9woM2xytU+Zt708NvhvD6TWHO1xquhPpnYxTu59oM+ZR\u002froLXSZD6q9qQhcg1EPjL8e0wX1CE+xCz63upE\u002fT3LFxzPkS7WPXC3okOLCq89zPakIXINhD1k\u00 ...

# %% [markdown]
# The plot above shows $|\Omega(z, t)|$ over the full simulation domain. Time $t$ is on the $x$-axis and propagation distance $z$ on the $y$-axis, so the field enters at the bottom. The dotted grey lines mark $z=0$ and $z=1$, the boundaries of the medium. The horizontal slice at $z=0$ represents the input field pulse.
#
# This result is presented in the speed-of-light reference frame: a pulse travelling at $c$ moves vertically in this plot. See [REF reference frame] for how to shift to the lab frame.

# %% [markdown]
# ### Analysis
#
# What happens in this simulation? We can see that the pulse is attenuated by the medium, in that the maximum of the peak leaving the medium at $z=1~\mathrm{cm}$ is lower than the maximum peak entering at $z=0~\mathrm{cm}$.
#
# We also see that the pulse is slightly fast, such that the peak arrives at the back of the medium, $z=1~\mathrm{cm}$, at
# a time $t < 0~\mathrm{\mu s}$ in this speed-of-light reference frame. This is typical of propagation through a medium with a normal dispersion profile. [Spectral Analysis](spectral-analysis.ipynb). There's a little bit of ringing after (to the right) of the pulse, seen in the lighter region.

# %% [markdown]
# ## Defining the System with JSON
#
# We went through defining `Field`, `Atom` and `MBSolve` objects separately so I could introduce these concepts, but in practice it is rare that we will need to interact with these directly. The whole problem can be defined via a JSON file or string, and this is the approach used throughout the rest of the documentation.

# %% [markdown]
# ## Spontaneous Decay
#
# To include spontaneous decay in the Lindblad master equation we have to add collapse operators. We add a list of `decays` into the `atom`, each with a list of channels describing the decays (ordered `lower` then `upper`) and a decay rate in the same units as the Rabi frequency (in this case $2\pi \mathrm{~ MHz}$). Here the decay rate is $2\pi \cdot 1 \mathrm{~ MHz}$. We also increase `interaction_strength` to $1.0$ so that absorption is clearly visible in the analysis plots below.

# %%
mbs_json = """
{
  "atom": {
    "decays": [
      {
        "channels": [[0, 1]],
        "rate": 1.0
      }
    ],
    "fields": [
      {
        "coupled_levels": [[0, 1]],
        "rabi_freq": 1.0e-3,
        "rabi_freq_t_args": {
          "ampl": 1.0,
          "centre": 0.0,
          "fwhm": 1.0
        },
        "rabi_freq_t_func": "gaussian"
      }
    ],
    "num_states": 2
  },
  "t_min": -2.0,
  "t_max": 10.0,
  "t_steps": 100,
  "z_min": -0.5,
  "z_max": 1.5,
  "z_steps": 20,
  "interaction_strengths": [
    1.0
  ]
}
"""

mbs = mb_solve.MBSolve().from_json_str(mbs_json)
Omegas_zt, states_zt = mbs.mbsolve()
# Out:
# 100%|██████████| 20/20 [00:00<00:00, 182.56z/s, Ω_max=0.003]

# %%
fig = plot.field_spacetime(mbs, show_z_bounds=(0.0, 1.0))
fig.show(renderer='notebook_connected')
# Out:
#         <script>
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.5.0.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="3a12fff9-4e31-4487-8f6e-4db409719507" class="plotly-graph-div" style="height:400px; width:700px;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("3a12fff9-4e31-4487-8f6e-4db409719507")) {                    Plotly.newPlot(                        "3a12fff9-4e31-4487-8f6e-4db409719507",                        [{"colorbar":{"title":{"text":"|Ω| (γ)"}},"colorscale":[[0.0,"rgb(247,251,255)"],[0.125,"rgb(222,235,247)"],[0.25,"rgb(198,219,239)"],[0.375,"rgb(158,202,225)"],[0.5,"rgb(107,174,214)"],[0.625,"rgb(66,146,198)"],[0.75,"rgb(33,113,181)"],[0.875,"rgb(8,81,156)"],[1.0,"rgb(8,48,107)"]],"x":{"dtype":"f8","bdata":"AAAAAAAAAMAUrkfhehT+vylcj8L1KPy\u002fPgrXo3A9+r9SuB6F61H4v2ZmZmZmZva\u002fexSuR+F69L+QwvUoXI\u002fyv6RwPQrXo\u002fC\u002fcD0K16Nw7b+amZmZmZnpv8T1KFyPwuW\u002f7FG4HoXr4b8oXI\u002fC9Sjcv3wUrkfhetS\u002foJmZmZmZyb+AFK5H4Xq0v4AUrkfheqQ\u002fgBSuR+F6xD\u002foUbgehevRP5iZmZmZmdk\u002fpHA9Ctej4D94FK5H4XrkP1C4HoXrUeg\u002fKFyPwvUo7D8AAAAAAADwP+xRuB6F6\u002fE\u002f1qNwPQrX8z\u002fC9Shcj8L1P65H4XoUrvc\u002fmJmZmZmZ+T+E61G4HoX7P3A9CtejcP0\u002fXI\u002fC9Shc\u002fz+kcD0K16MAQJqZmZmZmQFAkML1KFyPAkCE61G4HoUDQHoUrkfhegRAcD0K16NwBUBmZmZmZmYGQFyPwvUoXAdAUrgehetRCEBI4XoUrkcJQDwK16NwPQpAMjMzMzMzC0AoXI\u002fC9SgMQB6F61G4Hg1AFK5H4XoUDkAK16NwPQoPQAAAAAAAABBAexSuR+F6EED2KFyPwvUQQHA9CtejcBFA61G4HoXrEUBmZmZmZmYSQOF6FK5H4RJAXI\u002fC9ShcE0DXo3A9CtcTQFK4HoXrURRAzMzMzMzMFEBH4XoUrkcVQML1KFyPwhVAPQrXo3A9FkC4HoXrUbgWQDMzMzMzMxdArkfhehSuF0AoXI\u002fC9SgYQKRwPQrXoxhA
J9k2iVK+KKUTom2AsrNAlTycC3gCrE+x8zvIjyKbIbKyKJ+GIpwihNUnjt0Sgy0reeeUg\u002fKJEd\u002f20FM6kneRBoGaa9EieTcYu2Zbx5JsZxi7ZlvHk+qnYXNQ1llz65ZSxAaKKzPk02uZ97bc4+PTwa0YLE5T5FmWKvIcH8PiXIawDLiBE\u002fp+luYlu+Iz9eNhjTZ4Y0P66ipJEos0M\u002f8SZylex0UT8qv5nIT5BcP7wGsO1Jk2U\u002fb3O2cZIXbj8bnvjx9F9zP2Cq6eDHCHc\u002fT7sZK4VIeT+3H9YnPJ95P\u002fUZ0nD5+Hc\u002fea+rRzu1dD\u002f4rG0g3INwP+VQcEkYUmg\u002fQjckI42IYD9t\u002f4DMAMFUP7Pbdj9tDUg\u002fw3GLtmW8OT8n3jzbgmwpP8TovmkmMBc\u002fAgj8rpyGAz\u002fJfhF0OVzuPn9woM2xytU+Zt7 ...

# %%
# Animated spatial profile — use the slider or Play to watch the pulse propagate
fig = plot.field_z_profile_anim(mbs)
fig.show(renderer='notebook_connected')
# Out:
#         <script>
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.5.0.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="f2085868-c25c-4885-9ac9-805157b736e4" class="plotly-graph-div" style="height:400px; width:700px;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("f2085868-c25c-4885-9ac9-805157b736e4")) {                    Plotly.newPlot(                        "f2085868-c25c-4885-9ac9-805157b736e4",                        [{"fill":"tozeroy","fillcolor":"rgba(33, 113, 181, 0.2)","line":{"color":"#2171B5"},"mode":"lines","showlegend":false,"x":{"dtype":"f8","bdata":"AAAAAAAA4L+amZmZmZnZvzMzMzMzM9O\u002fmJmZmZmZyb+YmZmZmZm5vwAAAAAAAAAAoJmZmZmZuT+cmZmZmZnJPzQzMzMzM9M\u002fmpmZmZmZ2T8AAAAAAADgPzQzMzMzM+M\u002faGZmZmZm5j+amZmZmZnpP87MzMzMzOw\u002fAAAAAAAA8D+amZmZmZnxPzQzMzMzM\u002fM\u002fzczMzMzM9D9nZmZmZmb2PwAAAAAAAPg\u002f"},"y":{"dtype":"f8","bdata":"xnGLtmW8eT7GcYu2Zbx5PsZxi7ZlvHk+xnGLtmW8eT7GcYu2Zbx5PsZxi7ZlvHk+xnGLtmW8eT7GcYu2Zbx5PsZxi7ZlvHk+xnGLtmW8eT7GcYu2Zbx5PsZxi7ZlvHk+xnGLtmW8eT7GcYu2Zbx5PsZxi7ZlvHk+xnGLtmW8eT7GcYu2Zbx5PsZxi7ZlvHk+xnGLtmW8eT7GcYu2Zbx5PsZxi7ZlvHk+"},"type":"scatter"}],                        {"height":400,"sliders":[{"active":0,"currentvalue":{"prefix":"t = ","visible":true,"xanchor":"right"},"len":0.9,"pad":{"b":10,"t":50},"steps":[{"args":[["0"],{"frame":{"duration":0,"redraw":false},"mode":"immediate","transition":{"duration":0}}],"label":"-2.00","method":"animate"},{"args":[["1"],{"frame":{"duration":0,"redraw":false},"mode":"immediate","transition":{"duration":0}}],"label":"-1.88","method":"animate"},{"args":[["2"],{"frame":{"duration":0,"redraw":false},"mode":"immediate","transition":{"duration":0}}],"label":"-1.76","method":"animate"},{"args":[["3"],{"frame":{"duration":0,"redraw":false},"mode":"immediate","transition":{"duration":0}}],"label":"-1.64","method":"animate"},{"args":[["4"],{"frame":{"duration":0,"redraw":false},"mode":"immediate","transition":{"duration":0}}],"label":"-1.52","method":"animate"},{"args":[["5"],{"frame":{"duration":0,"redraw":false},"mode":"immediate","transition":{"duration":0}}],"label":"-1.40","method":"animate"},{"args":[["6"],{"frame":{"duration":0,"redraw":false},"mode":"immediate","transition":{"duration":0}}],"label":"-1.28","method":"animate"},{"args":[["7"],{"frame":{"duration":0,"redraw":false},"mode":"immediate","transition":{"duration":0}}],"label":"-1.16","method":"animate"},{"args":[["8"],{"frame":{"duration":0,"redraw":false},"mode":"immediate","transition":{"duration":0}}],"label":"-1.04","method":"animate"},{"args":[["9"],{"frame":{"duration":0,"redraw":false},"mode":"immediate","transition":{"duration":0}}],"label":"-0.92","method":"animate"},{"args":[["10"],{"frame":{"duration":0,"redraw":false},"mode":"immediate","transition":{"duration":0}}],"label":"-0.80","method":"animate"},{"args":[["11"],{"frame":{"duration":0,"redraw":false},"mode":"immediate","transition":{"duration":0}}],"label":"-0.68","method":"animate"},{"args":[["12"],{"frame":{"duration":0,"redraw":false},"mode":"immediate","transition":{"duration":0}}],"label":"-0.56","method":"animate"},{"args":[["13"],{"frame":{"duration":0,"redraw":false},"mode":"immediate","transition":{"duration":0}}],"label":"-0.44","method":"animate"},{"args":[["14"],{"frame":{"duration":0,"redraw":false},"mode":"immediate","transition":{"duration":0}}],"label":"-0.32","method":"animate"},{"args":[["15"],{"frame":{"duration":0,"redraw":false},"mode":"immediate","transition":{"duration":0}}],"label":"-0.20","method":"animate"},{"args":[["16"],{"frame":{"duration":0,"redraw":false},"mode":"immediate","transition":{"duration":0}}],"label":"-0.08","method":"animate"},{"args":[["17"],{"frame":{"duration":0,"redraw":false},"mode":"immediate","transition":{"duration":0}}],"label":"0.04","method":"animate"},{"args":[["18"],{"frame":{"duration":0, ...

# %%
# Pulse area vs z — should decrease as the probe is absorbed
fig = plot.pulse_area(mbs)
fig.show(renderer='notebook_connected')
# Out:
#         <script>
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.5.0.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="8f049dc9-0a15-4834-8cd0-067b4bd7bf52" class="plotly-graph-div" style="height:400px; width:700px;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("8f049dc9-0a15-4834-8cd0-067b4bd7bf52")) {                    Plotly.newPlot(                        "8f049dc9-0a15-4834-8cd0-067b4bd7bf52",                        [{"fill":"tozeroy","fillcolor":"rgba(217, 72, 1, 0.2)","line":{"color":"#D94801"},"mode":"lines","x":{"dtype":"f8","bdata":"AAAAAAAA4L+amZmZmZnZvzMzMzMzM9O\u002fmJmZmZmZyb+YmZmZmZm5vwAAAAAAAAAAoJmZmZmZuT+cmZmZmZnJPzQzMzMzM9M\u002fmpmZmZmZ2T8AAAAAAADgPzQzMzMzM+M\u002faGZmZmZm5j+amZmZmZnpP87MzMzMzOw\u002fAAAAAAAA8D+amZmZmZnxPzQzMzMzM\u002fM\u002fzczMzMzM9D9nZmZmZmb2PwAAAAAAAPg\u002f"},"y":{"dtype":"f8","bdata":"HWfUILFwYT8dZ9QgsXBhPx1n1CCxcGE\u002fHWfUILFwYT8dZ9QgsXBhPwSvUfhNmmA\u002f\u002fXb7FH5KXj8aLiUFGLtbPyBrFIzyeVk\u002fJFItual0Vz80CcHFJqBVP0ZuDwpLAFQ\u002f8BBsl3SEUj+KdrT0riNRPz3bgdhI6k8\u002fbk8uO1HGTj9uTy47UcZOP25PLjtRxk4\u002fbk8uO1HGTj9uTy47UcZOP25PLjtRxk4\u002f"},"type":"scatter"}],                        {"height":400,"template":{"layout":{"colorscale":{"diverging":[[0.0,"rgb(103,0,31)"],[0.1,"rgb(178,24,43)"],[0.2,"rgb(214,96,77)"],[0.3,"rgb(244,165,130)"],[0.4,"rgb(253,219,199)"],[0.5,"rgb(247,247,247)"],[0.6,"rgb(209,229,240)"],[0.7,"rgb(146,197,222)"],[0.8,"rgb(67,147,195)"],[0.9,"rgb(33,102,172)"],[1.0,"rgb(5,48,97)"]],"sequential":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]]},"colorway":["#4477AA","#EE6677","#228833","#CCBB44","#66CCEE","#AA3377","#BBBBBB"],"font":{"family":"sans-serif","size":13},"legend":{"bgcolor":"rgba(255,255,255,0.8)","bordercolor":"#cccccc","borderwidth":1},"margin":{"b":60,"l":60,"r":20,"t":50},"paper_bgcolor":"white","plot_bgcolor":"white","xaxis":{"gridcolor":"#e0e0e0","linecolor":"#888888","mirror":false,"showgrid":true,"showline":true,"ticks":"inside","zeroline":true,"zerolinecolor":"#aaaaaa","zerolinewidth":1},"yaxis":{"gridcolor":"#e0e0e0","linecolor":"#888888","mirror":false,"showgrid":true,"showline":true,"ticks":"inside","zeroline":true,"zerolinecolor":"#aaaaaa","zerolinewidth":1}}},"title":{"text":"Pulse area vs z — field 0"},"width":700,"xaxis":{"title":{"text":"z"},"minallowed":-0.5,"maxallowed":1.5},"yaxis":{"title":{"text":"area (π)"}}},                        {"responsive": true}                    ).then(function(){
#
# var gd = document.getElementById('8f049dc9-0a15-4834-8cd0-067b4bd7bf52');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };            </script>        </div>

# %%
# Input (z=z_min) vs output (z=z_max) pulse shape
fig = plot.field_envelope(mbs, z_indices=[0, -1])
fig.show(renderer='notebook_connected')
# Out:
#         <script>
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.5.0.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="bf291bea-f822-49c8-b954-28c183e71796" class="plotly-graph-div" style="height:400px; width:700px;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("bf291bea-f822-49c8-b954-28c183e71796")) {                    Plotly.newPlot(                        "bf291bea-f822-49c8-b954-28c183e71796",                        [{"fill":"tozeroy","fillcolor":"rgba(33, 113, 181, 0.2)","line":{"color":"#2171B5"},"mode":"lines","name":"z = -0.50","x":{"dtype":"f8","bdata":"AAAAAAAAAMAUrkfhehT+vylcj8L1KPy\u002fPgrXo3A9+r9SuB6F61H4v2ZmZmZmZva\u002fexSuR+F69L+QwvUoXI\u002fyv6RwPQrXo\u002fC\u002fcD0K16Nw7b+amZmZmZnpv8T1KFyPwuW\u002f7FG4HoXr4b8oXI\u002fC9Sjcv3wUrkfhetS\u002foJmZmZmZyb+AFK5H4Xq0v4AUrkfheqQ\u002fgBSuR+F6xD\u002foUbgehevRP5iZmZmZmdk\u002fpHA9Ctej4D94FK5H4XrkP1C4HoXrUeg\u002fKFyPwvUo7D8AAAAAAADwP+xRuB6F
DdOB\u002f+tvN1oN+kmcpXsdBE3OdoJXhGhtjb4MDjOOhVbNjaX5Pv47P01Gq4USHGHnjWzmGKvIcE8Nbo+aFwiAdk0DeFwZCQTdDQRhD7Um8INNCkYSrHFXaQz4HGLtmW8OTOBVoUAgQbOMkvODy+0K2Ayturc3c8U8DE4aWhKsYd9MXMlILw8CAkxVsTASUWXkzCluI\u002fBuE8cMI8tQAMK46Iv0U6s4u5DJy+CYxVUn3WqLivH4ylbyCsusUrL3uPuqi0EX\u002fV5GRsoLTnJanJm66Ms3kZNUNlkHixM5zJ9k2iVK+KKUTom2AsrNAlTycC3gCrE+x8zvIjyKbIbKyKJ+GIpwihNUnjt0Sgy0reeeUg\u002fKJEd\u002f20FM6kneRBoGaa9EieTcYu2Zbx5Jg=="},"type":"scatter"},{"fill":"tozeroy","fillcolor":"rgba(33, 113, 181, 0.2)","line":{"color":"#2171B5"},"mode":"lines","name":"z = 1.50","x":{"dtype":"f8","bdata":"AAAAAAAAAMAUrkfhehT+vylcj8L1KPy\u002fPgrXo3A9+r9SuB6F61H4v2ZmZmZmZva\u002fexSuR+F69L+QwvUoXI\u002fyv6RwPQrXo\u002fC\u002fcD0K16Nw7b+amZmZmZnpv8T1KFyPwuW\u002f7FG4HoXr4b8oXI\u002fC9Sjcv3wUrkfhetS\u002foJmZmZmZyb+AFK5H4Xq0v4AUrkfheqQ\u002fgBSuR+F6xD\u002foUbgehevRP5iZmZmZmdk\u002fpHA9Ctej4D94FK5H4XrkP1C4HoXrUeg\u002fKFyPwvUo7D8AAAAAAADwP+xRuB6F6\u002fE\u002f1qNwPQrX8z\u002fC9Shcj8L1P65H4XoUrvc\u002fmJmZmZmZ+T+E61G4HoX7P3A9CtejcP0\u002fXI\u002fC9Shc\u002fz+kcD0K16MAQJqZmZmZmQFAkML1KFyPAkCE61G4HoUDQHoUrkfhegRAcD0K16NwBUBmZmZmZmYGQFyPwvUoXAdAUrgehetRCEBI4XoUrkcJQDwK16NwPQpAMjMzMzMzC0AoXI\u002fC9SgMQB6F61G4Hg1AFK5H4XoUDkAK16NwPQoPQAAAAAAAABBAexSuR+F6EED2KFyPwvUQQHA9CtejcBFA61G4Ho ...
#
# var gd = document.getElementById('bf291bea-f822-49c8-b954-28c183e71796');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             cons

# %% [markdown]
# ## Using a Natural Unit System

# %% [markdown]
# It is possible to use any reciprocal angular momentum and time units (e.g. $2\pi \mathrm{~ MHz}$ and $\mathrm{~ \mu s}$ in the above example). The length unit is also arbitrary (e.g. $\mathrm{cm}$) as long as the interaction strength $Ng$ is given in the same units (e.g. $\mathrm{2\pi~MHz~/cm}$).
#
# For a two-level system we have a single natural linewidth, and so it is convenient to introduce a natural unit system, with frequencies in units of the natural linewidth $\Gamma$, times in units of the reciprocal spontaneous decay lifetime $\tau = 1/\Gamma$ and distances in units of the length of the medium $L$.
#
# By introducing this natural unit system we are able to reduce the number of parameters involved in the mathematical problem. For example, it becomes clear that increasing the length of the medium ten times is equivalent to raising the number density by the same scale, or by choosing a system with a suitably higher dipole moment.
#
# For most examples in this documentation from now on, we will use this natural unit system.

# %% [markdown]
# ## Shifting to the Fixed Frame of Reference
#
# We solve the problem in a frame of reference that moves with the speed of light across the medium. This means we can keep time in the system separate from distance, which makes the coupled equations easier to solve. We can also see all the important details of the solution in this frame of reference, as in the plots above. But if we want to look at how a field actually propagates in time, we need to shift back to a fixed (or laboratory) frame of reference. To do that we need to connect the time and space dimensions via the speed of light in the system. The utilities for this shift are in the `fixed` module.

# %%
from maxwellbloch import fixed

# %% [markdown]
# We define the speed of light based on the units in the system. For example, in the units above, $c \approx 3 \times 10^4 ~ \mathrm{cm / \mu s }$. If I put that speed in to the simulation results above, you will see no difference in the output. It will be too fast, and appear that the pulse progresses through the medium instantanously. Instead we can put in a slow speed-of-light to get an idea of what the shift does, say $10^{-5} c$. Something like looking at the pulse in slow motion.

# %%
speed_of_light = 0.3  # [cm /μs] THIS IS 10^5 SLOWER THAN C!

tlist_fixed_frame = fixed.t_list(mbs, speed_of_light)
field_fixed_frame = fixed.rabi_freq(mbs, 0, speed_of_light, part="abs")

# %%
fig = plot.field_spacetime(mbs, speed_of_light=speed_of_light, show_z_bounds=(0.0, 1.0))
fig.show(renderer='notebook_connected')
# Out:
#         <script>
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.5.0.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.5.0.min.js" integrity="sha256-fHbNLP+GlIXN+efbQec78UkemUz3NJp7UmfGxC1tNxs=" crossorigin="anonymous"></script>                <div id="0307a091-56a3-410e-8902-348d2ecd5167" class="plotly-graph-div" style="height:400px; width:700px;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("0307a091-56a3-410e-8902-348d2ecd5167")) {                    Plotly.newPlot(                        "0307a091-56a3-410e-8902-348d2ecd5167",                        [{"colorbar":{"title":{"text":"|Ω| (γ)"}},"colorscale":[[0.0,"rgb(247,251,255)"],[0.125,"rgb(222,235,247)"],[0.25,"rgb(198,219,239)"],[0.375,"rgb(158,202,225)"],[0.5,"rgb(107,174,214)"],[0.625,"rgb(66,146,198)"],[0.75,"rgb(33,113,181)"],[0.875,"rgb(8,81,156)"],[1.0,"rgb(8,48,107)"]],"x":{"dtype":"f8","bdata":"AAAAAAAACMCPwvUoXI8GwB+F61G4HgXArkfhehSuA8A+CtejcD0CwMzMzMzMzADAuB6F61G4\u002fr\u002fYo3A9Ctf7v\u002fYoXI\u002fC9fi\u002fFK5H4XoU9r80MzMzMzPzv1O4HoXrUfC\u002f4noUrkfh6r8ehetRuB7lv7oehetRuN6\u002fODMzMzMz07\u002fAHoXrUbi+v8AehetRuK4\u002fwB6F61G4zj\u002fcehSuR+HaPzIzMzMzM+M\u002f9ihcj8L16D+0HoXrUbjuPzwK16NwPfI\u002fHoXrUbge9T8AAAAAAAD4P+J6FK5H4fo\u002fwfUoXI\u002fC\...\u002fCIUAehetRuB4iQHsUrkfheiJA1qNwPQrXIkA0MzMzMzMjQI\u002fC9ShcjyNA7FG4HoXrI0BI4XoUrkckQKNwPQrXoyRAAAAAAAAAJUBcj8L1KFwlQLgehetRuCVAFK5H4XoUJkBxPQrXo3AmQMzMzMzMzCZAKFyPwvUoJ0CF61G4HoUnQOB6FK5H4SdAPgrXo3A9KECZmZmZmZkoQPYoXI\u002fC9ShAUrgehetRKUCtR+F6FK4pQArXo3A9CipAZmZmZmZmKkDC9Shcj8IqQB6F61G4HitAexSuR+F6K0DWo3A9CtcrQDQzMzMzMyxAj8L1KFyPLEDqUbgehessQEjhehSuRy1Ao3A9CtejLUAAAAAAAAAuQA=="},"y":{"dtype":"f8","bdata":"AAAAAAAA4L+amZmZmZnZvzMzMzMzM9O\u002fmJmZmZmZyb+YmZmZmZm5vwAAAAAAAAAAoJmZmZmZuT+cmZmZmZnJPzQzMzMzM9M\u002fmpmZmZmZ2T8AAAAAAADgP